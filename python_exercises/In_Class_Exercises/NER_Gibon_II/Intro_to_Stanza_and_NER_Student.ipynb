# %% [markdown]
# **Introduction to Stanza and Named Entity Recognition**

# %% [markdown]
# Link to stanza documentation: https://stanfordnlp.github.io/stanza/

# %% [markdown]
# More documentation with examples, geared towards beginners: https://github.com/stanfordnlp/stanza/blob/main/demo/Stanza_Beginners_Guide.ipynb

# %% [markdown]
# Optional Reading: https://www.newfireglobal.com/learn/natural-language-understanding-tools/#informed
# Article that covers some of the main differences between spacy and stanza with examples

# %% [markdown]
# **Imports**

# %%
import os
import pandas as pd

# %%
import stanza

# %%
! pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.6.1-py3-none-any.whl (881 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 9.7 MB/s eta 0:00:00a 0:00:01
# Collecting emoji (from stanza)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /Users/Max/miniconda3/lib/python3.11/site-packages (from stanza) (1.26.1)
# Collecting protobuf>=3.15.0 (from stanza)
#   Downloading protobuf-4.24.4-cp37-abi3-macosx_10_9_universal2.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.4/409.4 kB 30.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/Max/miniconda3/lib/python3.11/site-packages (from stanza) (2.29.0)
# Collecting torch>=1.3.0 (from stanza)
#   Downloading torch-2.1.0-cp311-none-macosx_11_0_arm64.whl (59.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 23.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /Users/Max/miniconda3/lib/python3.11/site-packages (from stanza) (4.65.0)
# Collecting filelock (from torch>=1.3.0->stanza)
#   Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions in /Users/Max/miniconda3/lib/python3.11/site-packages (from torch>=1.3.0->stanza) (4.7.1)
# Collecting sympy (from torch>=1.3.0->stanza)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 22.9 MB/s eta 0:00:00a 0:00:01
# Collecting networkx (from torch>=1.3.0->stanza)
#   Downloading networkx-3.2-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /Users/Max/miniconda3/lib/python3.11/site-packages (from torch>=1.3.0->stanza) (3.1.2)
# Collecting fsspec (from torch>=1.3.0->stanza)
#   Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Max/miniconda3/lib/python3.11/site-packages (from requests->stanza) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Max/miniconda3/lib/python3.11/site-packages (from requests->stanza) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Max/miniconda3/lib/python3.11/site-packages (from requests->stanza) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Max/miniconda3/lib/python3.11/site-packages (from requests->stanza) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Max/miniconda3/lib/python3.11/site-packages (from jinja2->torch>=1.3.0->stanza) (2.1.1)
# Collecting mpmath>=0.19 (from sympy->torch>=1.3.0->stanza)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 35.3 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, protobuf, networkx, fsspec, filelock, emoji, torch, stanza
# Successfully installed emoji-2.8.0 filelock-3.12.4 fsspec-2023.10.0 mpmath-1.3.0 networkx-3.2 protobuf-4.24.4 stanza-1.6.1 sympy-1.12 torch-2.1.0

# %%
print(os.getcwd())  #this shows us the current working directory we are in 
                    #Printing it is useful for making your eventual file path as we will see below!
#make sure that you are in the directory and folder which contains the textfile
# Out:
# /Users/Max/Desktop/Intro to Digital Humanities/cls161_fall23/python_exercises/In_Class_Exercises/NER_Gibon_II

# %%
# %cd /Users/Max/Desktop/Intro to Digital Humanities/cls161_fall23/python_exercises/In_Class_Exercises/NER_Gibon_II
# Out:
# /Users/Max/Desktop/Intro to Digital Humanities/cls161_fall23/python_exercises/In_Class_Exercises/NER_Gibon_II

# %% [markdown]
# **Inputs**
# Stanza can handle multiple types of inputs for different tasks. For the purposes of this exercise, we are giving it a list of sentences (ie strings).
# If we weren't splitting the text by sentence ourselves beforehand, we would have to give it just strings (i.e.,the entire text file) and the pipeline would split the strings into sentences itself as part of the tokenization process

# %%
#Here, we are loading the stanza model for english language processing 
#We will go through what these different processors do in a bit!
# To prevent output capacity issues, we are pre tokenizing the text before we give it to the processors
nlp = stanza.Pipeline(lang='en', processors='tokenize, pos,lemma, depparse,ner',tokenize_pretokenized=True)
# Out:
# 2023-10-25 15:12:30 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/tokenize/combined.pt:   0%|    …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/pos/combined_charlm.pt:   0%|  …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/lemma/combined_nocharlm.pt:   0…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/depparse/combined_charlm.pt:   …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/ner/ontonotes_charlm.pt:   0%| …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/pretrain/conll17.pt:   0%|     …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/pretrain/fasttextcrawl.pt:   0%…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/backward_charlm/1billion.pt:   …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.6.0/models/forward_charlm/1billion.pt:   0…
# 2023-10-25 15:12:58 INFO: Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# | ner       | ontonotes_charlm  |
# =================================
#
# 2023-10-25 15:12:58 INFO: Using device: cpu
# 2023-10-25 15:12:58 INFO: Loading: tokenize
# 2023-10-25 15:12:58 INFO: Loading: pos
# 2023-10-25 15:12:59 INFO: Loading: lemma
# 2023-10-25 15:12:59 INFO: Loading: depparse
# 2023-10-25 15:12:59 INFO: Loading: ner
# 2023-10-25 15:12:59 INFO: Done loading processors!

# %%
#uses an f string with my current working directory #ands file name
#this is an example of when you can use f-strings to your advantage 
path= f'{(os.getcwd())}/gibbon_decline_volume1_chap21.txt' 
with open( path, encoding='utf-8', mode='r') as f:
        vol1_chap21 = f.read()

# %%
vol1_chap21 #looking at the text 
#luckily for us, the format of this file shows every sentence ends with a period and then one white space 
#so we can use .split to create a list of sentences
# Out:
# ' Persecution of heresy — The Schism of the Donatists — The Arian Controversy — Athanasius — Distracted state of the Church and the Empire under Constantine and his sons — Toleration of Paganism \n THE grateful applause of the clergy has consecrated the memory of a prince, who indulged their passions and promoted their interest. Constantine gave them security, wealth, honours, and revenge; and the support of the orthodox faith  was considered as the most sacred and important duty of the civil magistrate. The edict of Milan, the great charter of toleration, had confirmed to each individual of the Roman world the privilege of choosing and professing his own religion. But this inestimable privilege was soon violated: with the knowledge of truth the emperor imbibed the maxims of persecution; and the sects which dissented from the Catholic church were afflicted and oppressed by the triumph of Christianity. Constantine easily believed that the heretics, who presumed to dispute his opinions or to oppose his commands, were guilty of the most absurd and criminal obstinacy; and that a seasonable application of moderate severities might save those unhappy men from the danger of an everlasting condemnation. Not a moment was lost in excluding the ministers and teachers of the separated congregations from any share of the rewards and immunities which the emperor had so liberally bestowed on the orthodox clergy. But as the sectaries might still exist under the cloud of royal disgrace, the conquest of the East was immediately followed by an edict which announced their total destruction.(1) After a preamble filled with passion and  reproach, Constantine absolutely prohibits the assemblies of the heretics, and confiscates their public property to the use either of the revenue or of the Catholic church. The sects against whom the Imperial severity was directed appear to have been the adherents of Paul of Samosata; the Montanists of Phrygia, who maintained an enthusiastic succession of prophecy; the Novatians, who sternly rejected the temporal efficacy of repentance; the Marcionites and Valentinians, under whose leading banners the various Gnostics of Asia and Egypt had insensibly rallied; and perhaps the Manichaeans, who had recently imported from Persia a more artful composition of Oriental and Christian theology.(2) The design of extirpating the name, or at least  of restraining the progress, of these odious heretics, was prosecuted with vigour and effect. Some of the penal regulations were copied from the edicts of Diocletian; and this method of conversion was applauded by the same bishops who had felt the hand of oppression, and had pleaded for the rights of humanity. Two immaterial circumstances may serve, however, to prove that the mind of Constantine was not entirely corrupted by the spirit of zeal and bigotry. Before he condemned the Manichaeans and their kindred sects, he resolved to make an accurate inquiry into the nature of their religious principles. As if he distrusted the impartiality of his ecclesiastical counsellors, this delicate commission was intrusted to a civil magistrate, whose learning and moderation he justly esteemed, and of whose venal character he was probably ignorant. (3) The emperor was soon convinced that he had too hastily proscribed the orthodox faith and the exemplary morals of the Novatians, who had dissented from the church in some articles of discipline which were not perhaps essential to salvation. By a particular edict he exempted them from the general penalties of the law; (4) allowed them to build a  church at Constantinople; respected the miracles of their saints; invited their bishop, Acesius, to the council of Nice; and gently ridiculed the narrow tenets of his sect by a familiar jest, which from the mouth of a sovereign must have been received with applause and gratitude.(5)\n African Controversy, A.D. 312. \n The complaints and mutual accusations which assailed the\n throne of Constantine, as soon a ...

# %%
chap21_sents= vol1_chap21.split('. ')
chap21_sents   #even if it is not perfect, its good enough for our purposes 
#now we have one large list of every sentence in this chapter!
# Out:
# [' Persecution of heresy — The Schism of the Donatists — The Arian Controversy — Athanasius — Distracted state of the Church and the Empire under Constantine and his sons — Toleration of Paganism \n THE grateful applause of the clergy has consecrated the memory of a prince, who indulged their passions and promoted their interest',
#  'Constantine gave them security, wealth, honours, and revenge; and the support of the orthodox faith  was considered as the most sacred and important duty of the civil magistrate',
#  'The edict of Milan, the great charter of toleration, had confirmed to each individual of the Roman world the privilege of choosing and professing his own religion',
#  'But this inestimable privilege was soon violated: with the knowledge of truth the emperor imbibed the maxims of persecution; and the sects which dissented from the Catholic church were afflicted and oppressed by the triumph of Christianity',
#  'Constantine easily believed that the heretics, who presumed to dispute his opinions or to oppose his commands, were guilty of the most absurd and criminal obstinacy; and that a seasonable application of moderate severities might save those unhappy men from the danger of an everlasting condemnation',
#  'Not a moment was lost in excluding the ministers and teachers of the separated congregations from any share of the rewards and immunities which the emperor had so liberally bestowed on the orthodox clergy',
#  'But as the sectaries might still exist under the cloud of royal disgrace, the conquest of the East was immediately followed by an edict which announced their total destruction.(1) After a preamble filled with passion and  reproach, Constantine absolutely prohibits the assemblies of the heretics, and confiscates their public property to the use either of the revenue or of the Catholic church',
#  'The sects against whom the Imperial severity was directed appear to have been the adherents of Paul of Samosata; the Montanists of Phrygia, who maintained an enthusiastic succession of prophecy; the Novatians, who sternly rejected the temporal efficacy of repentance; the Marcionites and Valentinians, under whose leading banners the various Gnostics of Asia and Egypt had insensibly rallied; and perhaps the Manichaeans, who had recently imported from Persia a more artful composition of Oriental and Christian theology.(2) The design of extirpating the name, or at least  of restraining the progress, of these odious heretics, was prosecuted with vigour and effect',
#  'Some of the penal regulations were copied from the edicts of Diocletian; and this method of conversion was applauded by the same bishops who had felt the hand of oppression, and had pleaded for the rights of humanity',
#  'Two immaterial circumstances may serve, however, to prove that the mind of Constantine was not entirely corrupted by the spirit of zeal and bigotry',
#  'Before he condemned the Manichaeans and their kindred sects, he resolved to make an accurate inquiry into the nature of their religious principles',
#  'As if he distrusted the impartiality of his ecclesiastical counsellors, this delicate commission was intrusted to a civil magistrate, whose learning and moderation he justly esteemed, and of whose venal character he was probably ignorant',
#  '(3) The emperor was soon convinced that he had too hastily proscribed the orthodox faith and the exemplary morals of the Novatians, who had dissented from the church in some articles of discipline which were not perhaps essential to salvation',
#  'By a particular edict he exempted them from the general penalties of the law; (4) allowed them to build a  church at Constantinople; respected the miracles of their saints; invited their bishop, Acesius, to the council of Nice; and gently ridiculed the narrow tenets of his sect by a familiar jest, which from the mouth of a sovereign must have been received with applause and gratitude.(5)\n African Controversy, A.D',
#  '312',
#  '\n The complaints and mutual accusations which assailed the\n throne of Constantine, as soon as the death of Maxentius had\n submitted Africa to his victorious arms, were ill adapted to\n edify an imperfect proselyte',
#  'He learned with surprise that\n the provinces of that great country, from the confines of\n Cyrene to the Columns of Hercules, were distracted with\n religious discord.(6) The source of the division was derived \n from a double election in the church of Carthage, the second\n in rank and opulence of the ecclesiastical thrones of the\n West Caecilian and Majourinus were the two rival primates of\n Africa; and the death of the latter soon made room for\n Donatus, who, by his superior abilities and apparent\n virtues, was the firmest support of his party',
#  'The advantage\n which Cacilian might claim from the priority of his\n ordination was destroyed by the illegal, or at least\n indecent, haste with which it had been performed, without\n expecting the arrival of the bishops of Numidia',
#  'The\n authority of these bishops, who, to the number of seventy,\n condemned Caecilian, and consecrated Majorinus, is again\n weakened by the infamy of some of their personal characters;\n and by the female intrigues, sacrilegious bargains, and\n tumultuous proceedings, which are imputed to this Numidian\n council',
#  '(7) The bishops of the contending factions \n maintained, with equal ardour and obstinacy, that their\n adversaries were degraded, or at least dishonoured, by the\n odious crime of delivering the Holy Scriptures to the\n officers of Diocletian',
#  'From their mutual reproaches, as\n well as from the story of this dark transaction, it may\n justly be inferred that the late persecution had embittered\n the zeal, without reforming the manners, of the African\n Christians',
#  'That divided church was incapable of affording\n an impartial judicature; the controversy was solemnly tried\n in five successive tribunals, which were appointed by the\n emperor; and the whole proceeding, from the first appeal to\n the final sentence, lasted above three years',
#  'A severe\n inquisition, which was taken by the praetorian vicar and the\n proconsul of Africa, the report of two episcopal visitors\n who had been sent to Carthage, the decrees of the councils\n of Rome and of Arles, and the supreme judgment of\n Constantine himself in his sacred consistories were all\n favourable to the cause of Caecilian; and he was unanimously\n acknowledged by the civil and ecclesiastical powers as the\n true and lawful primate of Africa',
#  'The honours and estates\n of the church were attributed to his suffragan bishops, and\n it was not without difficulty that Constantine was satisfied\n with inflicting the punishment of exile on the principal\n leaders of the Donatist faction',
#  'As their cause was examined\n with attention, perhaps it was determined with justice.\n Perhaps their complaint was not without foundation, that the\n credulity of the emperor had been abused by the insidious\n arts of his favourite Osius',
#  'The influence of falsehood and\n corruption might procure the condemnation of the innocent,\n or aggravate the sentence of the guilty',
#  'Such an act,\n however, of injustice, if it concluded an importunate\n dispute, might be numbered among the transient evils of a\n despotic administration, which are neither felt nor\n remembered by posterity.\n \n Schism of the Donatists, A.D',
#  '315',
#  '\n But this incident, so inconsiderable that it scarcely\n deserves a place in history, was productive of a memorable\n schism, which afflicted the provinces of Africa above three\n hundred years, and was extinguished only with Christianity\n itself',
#  'The inflexible zeal of freedom and fanaticism\n animated the Donatists to refuse obedience to the usurpers,\n whose election they disputed, and whose spiritual powers\n they denied',
#  'Excluded from the civil and religious communion\n of mankind, they boldly excommunicated the rest of mankind\n who had embraced the impious party of Caecilian, and of the\n Traditors, from whom he derived his pretended ordination.\n They asserted with confidence, and almost with exultation,\n that the Apostolical succession was interrupted; that all\n the bishops of Europe and Asia were infected by the\n contagion of guilt and schism; and that the prerogatives of\n the catholic church were confined to the chosen portion of\n the African believers, who alone had preserved inviolate the\n integrity of their faith and discipline',
#  'This rigid theory\n was supported by the most uncharitable conduct',
#  'Whenever\n they acquired a proselyte, even from the distant provinces\n of the East, they carefully repeated the sacred rites of\n baptism(8) and ordination; as they rejected the validity of those which he had already received from the hands of\n heretics or schismatics',
#  'Bishops, virgins, and even spotless\n infants, were subjected to the disgrace of a public penance\n before they could be admitted to the communion of the\n Donatists',
#  'If they obtained possession of a church which had\n been used by their Catholic adversaries, they purified the\n unhallowed building with the same jealous care which a\n temple of idols might have required',
#  'They washed the\n pavement, scraped the walls, burnt the altar (which was\n commonly of wood), melted the consecrated plate, and cast\n the Holy Eucharist to the dogs, with every circumstance of\n ignominy which could provoke and perpetuate the animosity of\n religious factions.(9) Notwithstanding this irreconcilable \n aversion, the two parties, who were mixed and separated in\n all the cities of Africa, had the same language and manners,\n the same zeal and learning, the same faith and worship.\n Proscribed by the civil and ecclesiastical powers of the\n empire, the Donatists still maintained in some provinces,\n particularly in Numidia, their superior numbers; and four\n hundred bishops acknowledged the jurisdiction of their\n primate',
#  'But the invincible spirit of the sect sometimes\n preyed on its own vitals: and the bosom of their\n schismatical church was torn by intestine divisions',
#  'A\n fourth part of the Donatist bishops followed the independent\n standard of the Maximianists',
#  'The narrow and solitary path\n which their first leaders had marked out continued to\n deviate from the great society of mankind Even the\n imperceptible sect of the Rogatians could affirm, without a\n blush, that when Christ should descend to judge the earth,\n he would find his true religion preserved only in a few\n nameless villages of the Caesarean Mauritania.(10)\n The Trinitarian controversy',
#  '\n The schism of the Donatists was confined to Africa; the more\n diffusive mischief of the Trinitarian controversy\n successively penetrated into every part of the Christian\n world',
#  'The former was an accidental quarrel, occasioned by\n the abuse of freedom; the latter was a high and mysterious\n argument, derived from the abuse of philosophy',
#  'From the age\n of Constantine to that of Clovis and Theodoric, the temporal\n interests both of the Romans and barbarians were deeply\n involved in the theological disputes of Arianism',
#  'The\n historian may therefore be permitted respectfully to\n withdraw the veil of the sanctuary, and to deduce the\n progress of reason and faith, of error and passion, from the\n school of Plato to the decline and fall of the empire.\n \n The system of Plato',
#  'Before Christ 360',
#  '\n The genius of Plato, informed by his own meditation or by\n the traditional knowledge of :he priests of Egypt,(11) had \n ventured to explore the mysterious nature of the Deity',
#  'When\n he had elevated his mind to the sublime contemplation of the\n first self-existent, necessary cause of the universe, the\n Athenian sage was incapable of conceiving how the simple\n unity of his essence could admit the infinite variety of\n distinct and successive ideas which compose the model of the\n intellectual world; how a Being purely incorporeal could\n execute that perfect model, and mould with a plastic hand\n the rude and independent chaos',
#  'The vain hope of extricating\n himself from these difficulties, which must ever oppress the\n feeble powers of the human mind, might induce Plato to\n consider the divine nature under the threefold modification\n — of the first cause, the reason, or The Logos Logos, and the soul\n or spirit of the universe',
#  'His poetical imagination\n sometimes fixed and animated these metaphysical\n abstractions; the three archical or original principles\n were represented in the Platonic system as three Gods,\n united with each other by a mysterious and ineffable\n generation; and the Logos was particularly considered under\n the more accessible character of the Son of an Eternal\n Father, and the Creator and Governor of he world',
#  'Such\n appear to have been the secret doctrines which were\n cautiously whispered in the gardens of the Academy; and\n which, according to the more recent disciples of Plato,\n could not be perfectly understood till after an assiduous\n study of thirty years.(12)\n taught in the scool of Alexandria',
#  'Before Christ 300',
#  '\nThe arms of the Macedonians diffused over Asia and Egypt the\n language and learning of Greece; and the theological system\n of Plato was taught, with less reserve, and perhaps with\n some improvements, in the celebrated school of Alexandria.\n (13) A numerous colony of Jews had been invited, by the favour \n of the Ptolemies, to settle in their new capital.(14) While \n the bulk of the nation practised the legal ceremonies, and\n pursued the lucrative occupations of commerce, a few Hebrews\n of a more liberal spirit devoted their lives to religious\n and philosophical contemplation',
#  '(15) They cultivated with \n diligence, and embraced with ardour, the theological system\n of the Athenian sage',
#  'But their national pride would have\n been mortified by a fair confession of their former poverty:\n and they boldly marked, as the sacred inheritance of their\n ancestors, the gold and jewels which they had so lately\n stolen from their Egyptian masters',
#  'One hundred years before\n the birth of Christ, a philosophical treatise, which\n manifestly betrays the style and sentiments of the school of\n Plato, was produced by the Alexandrian Jews, and unanimously\n received as a genuine and valuable relic of the inspired\n Wisdom of Solomon',
#  '(16) A similar union of the Mosaic faith \n and the Grecian philosophy distinguishes the works of Philo,\n which were composed, for the most part, under the reign of\n Augustus.(17) The material soul of the universe(18) might \n offend the piety of the Hebrews; but they applied the\n character of the Logos to the Jehovah of Moses and the\n Patriarchs; and the Son of God was introduced upon earth,\n under a visible and even human appearance, to perform those\n familiar offices which seem incompatible with the nature and\n attributes of the Universal Cause.(19)\n Revealed by the Apostle St John, A.D',
#  '97',
#  '\nThe eloquence of Plato, the name of Solomon, the authority\n of the school of Alexandria, and the consent of the Jews and\n Greeks, were insufficient to establish the truth of a\n mysterious doctrine, which might please, but could not\n satisfy, a rational mind',
#  'A prophet, or apostle, inspired by\n the Deity, can alone exercise a lawful dominion over the\n faith of mankind: and the theology of Plato might have been\n for ever confounded with the philosophical visions of the\n Academy, the Porch, and the Lyccum, if the name and divine\n attributes of the Logos had not been confirmed by the\n celestial pen of the last and most sublime of the\n Evangelists',
#  '(20) The Christian Revelation, which was \n consummated under the reign of Nerva, disclosed to the world\n the amazing secret, that the LOGOS, who was with God from\n the beginning, and was God, who had made all things, and for\n whom all things had been made, was incarnate in the person\n of Jesus of Nazareth; who had been born of a virgin, and\n suffered death on the cross',
#  'Besides the general design of\n fixing on a perpetual basis the divine honours of Christ,\n the most ancient and respectable of the ecclesiastical\n writers have ascribed to the evangelic theologian a\n particular intention to confute two opposite heresies, which\n disturbed the peace of the primitive church.(21)\nThe Ebionites and Docetes\nI',
#  'The faith of the Ebionites, (22) perhaps of the Nazarenes,(23) was gross \n and imperfect',
#  'They revered Jesus as the greatest of the\n prophets, endowed with supernatural virtue and power',
#  'They\n ascribed to his person and to his future reign all the\n predictions of the Hewbrew oracles which relate to the\n spiritual and everlasting kingdom of the promised Messiah.\n (24) Some of them might confess that he was born of a virgin; \n but they obstinately rejected the preceding existence and\n divine perfections of the logos, or Son of God, which are so\n clearly defined in the Gospel of St',
#  'John',
#  'About fifty years\n afterwards, the Ebionites, whose errors are mentioned by\n Justin Martyr, with less severity than they seem to deserve,\n (25) formed a very inconsiderable portion of the Christian \n name',
#  'II',
#  'The Gnostics, who were distinguished by the\n epithet of Docetes, deviated into the contrary extreme, and\n betrayed the human, while they asserted the divine nature of\n Christ',
#  'Educated in the school of Plato, accustomed to the\n sublime idea of the Logos, they readily conceived that the\n brightest Aeon, or Emanation of the Deity, might assume the\n outward shape and visible appearances of a mortal;(26) but \n they vainly pretended that the imperfections of matter are\n incompatible with the purity of a celestial substance',
#  'While\n the blood of Christ yet smoked on Mount Calvary, the Docetes\n invented the impious and extravagant hypothesis, that,\n instead of issuing from the womb of the Virgin,(27) he had \n descended on the banks of the Jordan in the form of perfect\n manhood; that he had imposed on the senses of his enemies\n and of his disciples; and that the ministers of Pilate had\n wasted their impotent rage on an airy phantom, who seemed to\n expire on the cross, and, after three days, to rise from the\n dead.(28)\n Mysterious nature of the Trinity',
#  '\n The divine sanction which the Apostle had bestowed on the\n fundamental principle of the theology of Plato encouraged\n the learned proselytes of the second and third centuries to\n admire and study the writings of the Athenian sage, who had\n thus marvellously anticipated one of the most surprising\n discoveries of the Christian revelation',
#  'The respectable\n name of Plato was used by the orthodox,(29) and abused by the \n heretics,(30) as the common support of truth and error: the \n authority of his skilful commentators and the science of\n dialectics were employed to justify the remote consequences\n of his opinions, and to supply the discreet silence of the\n inspired writers',
#  'The same subtle and profound questions\n concerning the nature, the generation, the distinction, and\n the equality of the three divine persons of the mysterious\n Triad, or Trinity,(31) were agitated in the philosophical and in the Christian schools of Alexandria',
#  'An eager spirit of\n curiosity urged them to explore the secrets of the abyss;\n and the pride of the professors and of their disciples was\n satisfied with the science of words',
#  'But the most sagacious\n of the Christian theologians, the great Athanasius himself,\n has candidly confessed (32) that, whenever he forced his \n understanding to meditate on the divinity of the Logos, his\n toilsome and unavailing efforts recoiled on themselves; that\n the more he thought, the less he comprehended; and the more\n he wrote, the less capable was he of expressing his\n thoughts',
#  'In every step of the inquiry we are compelled to\n feel and acknowledge the immeasurable disproportion between\n the size of the object and the capacity of the human mind.\n We may strive to abstract the notions of time, of space, and\n of matter, which so closely adhere to all the perceptions of\n our experimental knowledge',
#  'But as soon as we presume to\n reason of infinite substance, of spiritual generation, as\n often as we deduce any positive conclusions from a negative\n idea, we are involved in darkness, perplexity, and\n inevitable contradiction',
#  'As these difficulties arise from\n the nature of the subject, they oppress, with the same\n insuperable weight, the philosophic and the theological\n disputant; but we may observe two essential and peculiar\n circumstances which discriminated the doctrines of the\n catholic church from the opinions of the Platonic school.\n \n Zeal of the Christians.\nI',
#  'A chosen society of philosophers, men of a liberal\n education and curious disposition, might silently meditate,\n and temperately discuss in the gardens of Athens or the\n library of Alexandria, the abstruse questions of\n metaphysical science',
#  'The lofty speculations, which neither\n convinced the understanding nor agitated the passions of the\n Platonists themselves, were carelessly overlooked by the\n idle, the busy, and even the studious part of mankind.(33) \n But after the logos had been revealed as the sacred object\n of the faith, the hope, and the religious worship of the\n Christians, the mysterious system was embraced by a numerous\n and increasing multitude in every province of the Roman\n world',
#  'Those persons who, from their age, or sex, or\n occupations, were the least qualified to judge, who were the\n least exercised in the habits of abstract reasoning, aspired\n to contemplate the economy of the Divine Nature: and it is\n the boast of Tertullian (34) that a Christian mechanic could \n readily answer such questions as had perplexed the wisest of\n the Grecian sages',
#  'Where the subject lies so far beyond our\n reach, the difference between the highest and the lowest of\n human understandings may indeed be calculated as infinitely\n small; yet the degree of weakness may perhaps be measured by\n the degree of obstinacy and dogmatic confidence',
#  'These\n speculations, instead of being treated as the amusement of a\n vacant hour, became the most serious business of the\n present, and the most useful preparation for a future life.\n A theology which it was incumbent to believe, which it was\n impious to doubt, and which it might be dangerous, and even\n fatal, to mistake, became the familiar topic of private\n meditation and popular discourse',
#  'The cold indifference of\n philosophy was inflamed by the fervent spirit of devotion;\n and even the metaphors of common language suggested the\n fallacious prejudices of sense and experience',
#  'The\n Christians, who abhorred the gross and impure generation of\n the Greek mythology, (35) were tempted to argue from the \n familiar analogy of the filial and paternal relations',
#  'The\n character of Son seemed to imply a perpetual subordination\n to the voluntary author of his existence;(36) but as the act \n of generation, in the most spiritual and abstracted sense,\n must be supposed to transmit the properties of a common\n nature,(37) they durst not presume to circumscribe the powers \n or the duration of the Son of an eternal and omnipotent\n Father',
#  'Four-score years after the death of Christ, the\n Christians of Bithynia declared before the tribunal of Pliny\n that they invoked him as a god: and his divine honours have\n been perpetuated in every age and country, by the various\n sects who assume the name of his disciples.(38) Their tender \n reverence for the memory of Christ, and their horror for the\n profane worship of any created being, would have engaged\n them to assert the equal and absolute divinity of the logos,\n if their rapid ascent towards the throne of heaven had not\n been imperceptibly checked by the apprehension of violating\n the unity and sole supremacy of the great Father of Christ,\n and of the Universe',
#  'The suspense and fluctuation produced\n in the minds of the Christians by these opposite tendencies\n may be observed in the writings of the theologians who\n flourished after the end of the apostolic age and before the\n origin of the Arian controversy',
#  'Their suffrage is claimed,\n with equal confidence, by the orthodox and by the heretical\n parties and the most inquisitive critics have fairly allowed\n that, if they had the good fortune of possessing the\n catholic verity, they have delivered their conceptions in\n loose, inaccurate, and sometimes contradictory language.(39)\n Authority of the church..\nII',
#  'The devotion of individuals was the first circumstance\n which distinguished the Christians from the Platonists: the\n second was the authority of the church',
#  'The disciples of\n philosophy asserted the rights of intellectual freedom, and\n their respect for the sentiments of their teachers was a\n liberal and voluntary tribute which they offered to superior\n reason',
#  'But the Christians formed a numerous and disciplined\n society; and the jurisdiction of their laws and magistrates\n was strictly exercised over the minds of the faithful',
#  'The\n loose wanderings of the imagination were gradually confined\n by creeds and confessions; (40) the freedom of private judgment submitted to the public wisdom of synods; the\n authority of a theologian was determined by his\n ecclesiastical rank; and the episcopal successors of the\n apostles inflicted the censures of the church on those who\n deviated from the orthodox belief',
#  'But in an age of\n religious controversy every act of oppression adds new force\n to the elastic vigour of the mind; and the zeal or obstinacy\n of a spiritual rebel was sometimes stimulated by secret\n motives of ambition or avarice',
#  ' Factions A metaphysical argument\n became the cause or pretence of political contests; the\n subtleties of the Platonic school were used as the badges of\n popular factions, and the distance which separated their\n respective tenets was enlarged or magnified by the acrimony\n of dispute',
#  'As long as the dark heresies of Praxeas and\n Sabellius laboured to confound the Father with the Son, (41) \n the orthodox party might be excused if they adhered more\n strictly and more earnestly to the distinction than to the\n equality of the divine persons',
#  'But as soon as the heat of\n controversy had subsided and the progress of the Sabellians\n was no longer an object of terror to the churches of Rome,\n of Africa, or of Egypt, the tide of theological opinion\n began to flow with a gentle but steady motion toward the\n contrary extreme; and the most orthodox doctors allowed\n themselves the use of the terms and definitions which had\n been censured in the mouth of the sectaries.(42) After the \n edict of toleration had restored peace and leisure to the\n Christians, the Trinitarian controversy was revived in the\n ancient seat of Platonism, the learned, the opulent, the\n tumultuous city of Alexandria; and the flame of religious\n discord was rapidly communicated from the schools to the\n clergy, the people, the provinces, and the East',
#  'The\n abstruse question of the eternity of the logos was agitated\n in ecclesiastic conferences and popular sermons; and the  Arius  heterodox opinions of Arius (43) were soon made public by his  own zeal and by that of his adversaries',
#  'His most implacable adversaries have acknowledged the learning and blameless life of the eminent presbyter, who, in a former election,\n had declined, and perhaps generously declined, his\n pretensions to the episcopal throne',
#  '(44) His competitor  Alexander assumed the office of his judge',
#  'The important\n cause was argued before him; and if at first he seemed to\n hesitate, he at length pronounced his final sentence as an\n absolute rule of faith',
#  '(45) The undaunted presbyter, who \n presumed to resist the authority of his angry bishop, was\n separated from the communion of the church',
#  'But the pride of\n Arius was supported by the applause of a numerous party',
#  'He\n reckoned among his immediate followers two bishops of Egypt,\n seven presbyters, twelve deacons, and (what may appear\n almost incredible) seven hundred virgins',
#  'A large majority\n of the bishops of Asia appeared to support or favour his\n cause; and their measures were conducted by Eusebius of\n Caesarea, the most learned of the Christian prelates; and by\n Eusebius of Nicomedia, who had acquired the reputation of a\n statesman without forfeiting that of a saint',
#  'Synods in\n Palestine and Bithynia were opposed to the synods of Egypt.\n The attention of the prince and people was attracted by this\n theological dispute; and the decision, at the end of six\n years,(46) was referred to the supreme authority of the  general council of Nice.\n \n Three systems of the Trinity',
#  '\nWhen the mysteries of the Christian faith were dangerously\n exposed to public debate, it might be observed that the\n human understanding was capable of forming three distinct,\n though imperfect, systems concerning the nature of the\n Divine Trinity, and it was pronounced that none of these\n systems, in a pure and absolute sense, were exempt from\n heresy and error',
#  '(47)\nArianism',
#  'I',
#  'According to the first hypothesis, which was maintained by Arius and his disciples, the logos\n was a dependent and spontaneous production, created from\n nothing by the will of the Father',
#  'The Son, by whom all\n things were made, (48) had been begotten before all worlds, \n and the longest of the astronomical periods could be\n compared only as a fleeting moment to the extent of his\n duration; yet this duration was not infinite,(49) and there \n had been a time which preceded the ineffable generation of\n the logos',
#  'On this only begotten Son the Almighty Father had\n transfused his ample spirit, and impressed the effulgence of\n his glory',
#  'Visible image of invisible perfection, he saw, at\n an immeasurable distance beneath his feet, the thrones of\n the brightest archangels; yet he shone only with a reflected\n light, and, like the sons of the Roman emperors, who were\n invested with the titles of Caesar or Augustus, (50) he \n governed the universe in obedience to the will of his Father\n and Monarch',
#  'Tritheism.\nII',
#  'In the second hypothesis, the logos\n possessed all the inherent, incommunicable perfections which\n religion and philosophy appropriate to the Supreme God.\n Three distinct and infinite minds or substances, three\n co-equal and co-eternal beings, composed the Divine Essence;\n (51) and it would have implied contradiction that any of them \n should not have existed, or that they should ever cease to\n exist',
#  '(52) The advocates of a system which seemed to \n establish three independent Deities attempted to preserve\n the unity of the First Cause, so conspicuous in the design\n and order of the world, by the perpetual concord of their\n administration and the essential agreement of their will',
#  'A\n faint resemblance of this unity of action may be discovered\n in the societies of men, and even of animals',
#  'The causes\n which disturb their harmony proceed only from the\n imperfection and inequality of their faculties; but the\n omnipotence which is guided by infinite wisdom and goodness\n cannot fail of choosing the same means for the\n accomplishment of the same ends',
#  '\nSabellianism.\nIII',
#  'Three beings, who, by the self-derived necessity of their existence, possess all  the divine attributes in the most perfect degree, who are\n eternal in duration, infinite in space, and intimately\n present to each other and to the whole universe,\n irresistibly force themselves on the astonished mind as one\n and the same Being,(53) who, in the economy of grace, as well \n as in that of nature, may manifest himself under different\n forms, and be considered under different aspects',
#  'By this\n hypothesis a real substantial trinity is refined into a\n trinity of names and abstract modifications that subsist\n only in the mind which conceives them',
#  'The logos is no\n longer a person, but an attribute; and it is only in a\n figurative sense that the epithet of Son can be applied to\n the eternal reason which was with God from the beginning,\n and by which, not by whom, all things were made',
#  'The\n incarnation of the logos is reduced to a mere inspiration of\n the Divine Wisdom, which filled the soul and directed all\n the actions of the man Jesus',
#  'Thus, after revolving round\n the theological circle, we are surprised to find that the\n Sabellian ends where the Ebionite had begun, and that the\n incomprehensible mystery which excites our adoration eludes\n our inquiry(54)\n Council of Nice, A.D',
#  '325',
#  '\n If the bishops of the council of Nice(55) had been permitted \n to follow the unbiassed dictates of their conscience, Arius\n and his associates could scarcely have flattered themselves\n with the hopes of obtaining a majority of votes in favour of\n an hypothesis so directly adverse to the two most popular\n opinions of the catholic world',
#  'The Arians soon perceived\n the danger of their situation, and prudently assumed those\n modest virtues which, in the fury of civil and religious\n dissensions, are seldom practised, or even praised, except\n by the weaker party',
#  'They recommended the exercise of\n Christian charity and moderation, urged the incomprehensible\n nature of the controversy, disclaimed the use of any terms\n or definitions which could not be found in the Scriptures,\n and offered, by very liberal concessions, to satisfy their\n adversaries without renouncing the integrity of their own\n principles',
#  'The victorious faction received all their\n proposals with haughty suspicion, and anxiously sought for\n some irreconcilable mark of distinction, the rejection of\n which might involve the Arians in the guilt and consequences\n of heresy',
#  'A letter was publicly read and ignominiously\n torn, in which their patron, Eusebius of Nicomedia,\n ingenuously confessed that the admission of the HOMOOUSION, or Consubstantial, a word already familiar to the Platonists, was incompatible with the principles of their\n theological system',
#  'The fortunate opportunity was eagerly\n embraced by the bishops, who governed the resolutions of the\n synod, and, according to the lively expressions of Ambrose,\n (56) they used the sword, which heresy itself had drawn from  the scabbard, to cut off the head of the hated monster',
#  'The consubstantiality of the Father and the Son was established\n by the council of Nice, and has been unanimously received as\n a fundamental article of the Christian faith by the consent\n of the Greek, the Latin, the Oriental, and the Protestant\n churches',
#  'But if the same word had not served to stigmatise\n the heretics and to unite the catholics, it would have been\n inadequate to the purpose of the majority by whom it was\n introduced into the orthodox creed',
#  'This majority was\n divided into two parties, distinguished by a contrary\n tendency to the sentiments of the Tritheists and of the\n Sabellians',
#  'But as those opposite extremes seemed to\n overthrow the foundations either of natural or revealed\n religion, they mutually agreed to qualify the rigour of\n their principles, and to disavow the just, but invidious,\n consequences which might be urged by their antagonists',
#  'The\n interest of the common cause inclined them to join their\n numbers and to conceal their differences; their animosity\n was softened by the healing counsels of toleration, and\n their disputes were suspended by the use of the mysterious\n Homoousion, which either party was free to interpret\n according to their peculiar tenets',
#  'The Sabellian sense,\n which, about fifty years before, had obliged the council of\n Antioch(57) to prohibit this celebrated term, had endeared it \n to those theologians who entertained a secret but partial\n affection for a nominal Trinity',
#  'But the more fashionable\n saints of the Arian times, the intrepid Athanasius, the\n learned Gregory Nazianzen, and the other pillars of the\n church, who supported with ability and success the Nicene\n doctrine, appeared to consider the expression of substance\n as if it had been synonymous with that of nature; and they\n ventured to illustrate their meaning by affirming that three\n men, as they belong to the same common species, are\n consubstantial or homoousian to each other.(58) This pure and \n distinct equality was tempered, on the one hand, by the\n internal connection and spiritual penetration which\n indissolubly unites the divine persons; (59) and, on the \n other, by the pre-eminence of the Father, which was\n acknowledged as far as it is compatible with the\n independence of the Son',
#  '(60) Within these limits the almost \n invisible and tremulous ball of orthodoxy was allowed\n securely to vibrate',
#  'On either side, beyond this consecrated\n ground, the heretics and the daemons lurked in ambush to\n surprise and devour the unhappy wanderer',
#  'But as the degrees\n of theological hatred depend on the spirit of the war rather\n than on the importance of the controversy, the heretics who\n degraded were treated with more severity than those who\n annihilated the person of the Son',
#  'The life of Athanasius\n was consumed in irreconcilable opposition to the impious\n madness of the Arians,(61) but he defended above twenty years \n the Sabellianism of Marcellus of Ancyra; and when at last he\n was compelled to withdraw himself from his communion, he\n continued to mention with an ambiguous smile the venial\n errors of his respectable friend.(62)\n Arian Creeds',
#  '\nThe authority of a general council, to which the Arians\n themselves had been compelled to submit, inscribed on the\n banners of the orthodox party the mysterious characters of\n the word Homoousion, which essentially contributed,\n notwithstanding some obscure disputes, some nocturnal\n combats, to maintain and perpetuate the uniformity of faith,\n or at least of language',
#  'The Consubstantialists, who by\n their success have deserved and obtained the title of\n Catholics, gloried in the simplicity and steadiness of their\n own creed, and insulted the repeated variations of their\n adversaries, who were destitute of any certain rule of\n faith',
#  'The sincerity or the cunning of the Arian chiefs, the\n fear of the laws or of the people, their reverence for\n Christ, their hatred of Athanasius, all the causes, human\n and divine, that influence and disturb the counsels of a\n theological faction, introduced among the sectaries a spirit\n of discord and inconstancy which in the course of a few\n years erected eighteen different models of religion,(63) and  avenged the violated dignity of the church',
#  'The zealous Hilary, (64) who, from the peculiar hardships of his  situation, was inclined to extenuate rather than to aggravate the errors of the Oriental clergy, declares that,\n in the wide extent of the ten provinces of Asia to which he\n had been banished, there could be found very few prelates\n who had preserved the knowledge of the true God.(65) The oppression which he had felt, the disorders of which he was the spectator and the victim, appeased, during a short interval, the angry passions of his soul and in the\n following passage, of which I shall transcribe a few lines,\n the bishop of Poitiers unwarily deviates into the style of a\n Christian philosopher',
#  ' Arian Sects \n It will not be expected, it would not perhaps be endured,\n that I should swell this theological digression by',
#  'a minute\n examination of the eighteen creeds, the authors of which,\n for the most part, disclaimed the odious name of their\n parent Arius',
#  'It is amusing enough to delineate the form,\n and to trace the vegetation, of a singular plant; but the\n tedious detail of leaves without flowers, and of branches\n without fruit, would soon exhaust the patience and\n disappoint the curiosity of the laborious student',
#  'One\n question, which gradually arose from the Arian controversy,\n may, however, be noticed, as it served to produce and\n discriminate the three sects who were united only by their\n common aversion to the Homoousion of the Nicene synod',
#  '1/.\n If they were asked whether the Son was like unto the Father,\n the question was resolutely answered in the negative by the\n heretics who adhered to the principles of Arius, or indeed\n to those of philosophy, which seem to establish an infinite\n difference between the Creator and the most excellent of his\n creatures',
#  'This obvious consequence was maintained by\n Aetius,(67) on whom the zeal of his adversaries bestowed the surname of the Atheist',
#  'His restless and aspiring spirit  urged him to try almost every profession of human life',
#  'He\n was successively a slave, or at least a husbandman, a\n travelling tinker, a goldsmith, a physician, a schoolmaster,\n a theologian, and at last the apostle of a new church, which\n was propagated by the abilities of his disciple Eunomius.(68)   Armed with texts of Scripture, and with captious syllogisms\n from the logic of Aristotle, the subtle Aetius had acquired\n the fame of an invincible disputant, whom it was impossible\n either to silence or to convince',
#  'Such talents engaged the\n friendship of the Arian bishops, till they were forced to\n renounce and even to persecute a dangerous ally, who, by the\n accuracy of his reasoning, had prejudiced their cause in the\n popular opinion, and offended the piety of their most\n devoted followers',
#  '2/',
#  'The omnipotence of the Creator\n suggested a specious and respectful solution of the likeness\n of the Father and the Son; and faith might humbly receive\n what reason could not presume to deny, that the Supreme God\n might communicate his infinite perfections, and create a\n being similar only to himself',
#  '(69) These Arians were \n powerfully supported by the weight and abilities of their\n leaders, who had succeeded to the management of the Eusebian\n interest, and who occupied the principal thrones of the\n East',
#  'They detested, perhaps with some affectation, the\n impiety of Aetius; they professed to believe, either without\n reserve or according to the Scriptures, that the Son was\n different from all other creatures, and similar only to the\n Father',
#  'But they denied that he was either of the same or of\n a similar substance; sometimes boldly justifying their\n dissent, and sometimes objecting to the use of the word\n substance, which seems to imply an adequate, or at least a\n distinct, notion of the nature of the Diety',
#  '3/',
#  'The sect\n which asserted the doctrine of a similar substance was the\n most numerous, at least in the provinces of Asia; and when\n the leaders of both parties were assembled in the council of\n Seleucia, (70) their opinion would have prevailed by a majority of one hundred and five to forty-three bishops',
#  'The\n Greek word which was chosen to express this mysterious\n resemblance bears so close an affinity to the orthodox\n symbol, that the profane of every age have derided the\n furious contests which the difference of a single diphthong\n excited between the Homoousians and the Homoiousians',
#  'As it\n frequently happens that the sounds and characters which\n approach the nearest to each other accidentally represent\n the most opposite ideas, the observation would be itself\n ridiculous, if it were possible to mark any real and\n sensible distinction between the doctrine of the\n Semi-Arians, as they were improperly styled, and that of the\n Catholics themselves',
#  'The bishop of Poitiers, who in his\n Phrygian exile very wisely aimed at a coalition of parties,\n endeavours to prove that, by a pious and faithful\n interpretation,(71) the Homoiousion may be reduced to a consubstantial sense',
#  'Yet he confesses that the word has a\n dark and suspicious aspect; and, as if darkness were\n congenial to theological disputes, the Semi-Arians, who\n advanced to the doors of the church, assailed them with the\n most unrelenting fury.\n \n Faith of the Western or Latin church \n The provinces of Egypt and Asia, which cultivated the\n language and manners of the Greeks, had deeply imbibed the\n venom of the Arian controversy',
#  'The familiar study of the\n Platonic system, a vain and argumentative disposition, a\n copious and flexible idiom, supplied the clergy and people\n of the East with an inexhaustible flow of words and\n distinctions; and, in the midst of their fierce contentions,\n they easily forgot the doubt which is recommended by\n philosophy, and the submission which is enjoined by\n religion',
#  'The inhabitants of the West were of a less\n inquisitive spirit, their passions were not so forcibly\n moved by invisible objects, their minds were less frequently\n exercised by the habits of dispute; and such was the happy\n ignorance of the Gallican church, that Hilary himself, above\n thirty years after the first general council, was still a\n stranger to the Nicene creed.(72) The Latins had received the \n rays of divine knowledge through the dark and doubtful\n medium of a translation',
#  'The poverty and stubbornness of\n their native tongue was not always capable of affording just\n equivalents for the Greek terms, for the technical words of\n the Platonic philosophy, (73) which had been consecrated, by \n the Gospel or by the church, to express the mysteries of the\n Christian faith, and a verbal defect might introduce into\n the Latin theology a long train of error or perplexity.(74) \n But as the western provincials had the good fortune of\n deriving their religion from an orthodox source, they\n preserved with steadiness the doctrine which they had\n accepted with docility; and when the Arian pestilence\n approached their frontiers, they were supplied with the\n seasonable preservative of the Homoousion by the paternal\n care of the Roman pontiff',
#  'Council of Rimi, A.D',
#  '360  Their sentiments and their temper\n were displayed in the memorable synod of Rimini, which\n surpassed in numbers the council of Nice, since it was\n composed of above four hundred bishops of Italy, Africa,\n Spain, Gaul, Britain, and Illyricum',
#  'From the first debates\n it appeared that only four score prelates adhered to the\n party, though they affected to anathematise the name and\n memory of Arius',
#  'But this inferiority was compensated by the\n advantages of skill, of experience, and of discipline; and\n the minority was conducted by Valens and Ursacius, two\n bishops of Illyricum, who had spent their lives in the\n intrigues of courts and councils, and who had been trained\n under the Eusebian banner in the religious wars of the East.\n By their arguments and negotiations they embarrassed, they\n confounded, they at last deceived the honest simplicity of\n the Latin bishops, who suffered the palladium of the faith\n to be extorted from their hands by fraud and importunity,\n rather than by open violence',
#  'The council of Rimini was not\n allowed to separate till the members had imprudently\n subscribed a captious creed, in which some expressions,\n susceptible of an heretical sense, were inserted in the room\n of the Homoousion',
#  'It was on this occasion that, according\n to Jerom, the world was surprised to find itself Arian.(75) \n But the bishops of the Latin provinces had no sooner reached\n their respective dioceses than they discovered their\n mistake, and repented of their weakness',
# ...
#  'The\n successor of Constantius has expressed, in a concise but\n lively manner, some of the theological calamities which\n afflicted the empire, and more especially the East, in the\n reign of a prince who was the slave of his own passions, and\n of those of his eunuchs',
#  ' The revolt and fury of the Donatists Circumcellions, A.D',
#  '345 etc \n While the flames of the Arian controversy consumed the vitals of the empire, the African provinces were infested by their peculiar enemies, the savage fanatics, who, under the name of Circumcellions, formed the strength and scandal of the Donatist party',
#  '(157) The severe execution of the laws of  Constantine had excited a spirit of discontent and resistance; the strenuous efforts of his son Constans to restore the unity of the church exasperated the sentiments of mutual hatred which had first occasioned the separation; and the methods of force and corruption employed by the two Imperial commissioners, Paul and Macarius, furnished the schismatics with a specious contrast between the maxims of the apostles and the conduct of their pretended successors',
#  '(158) The peasants who inhabited the villages of Numidia and Mauritania were a ferocious race, who had been imperfectly reduced under the authority of the Roman laws, who were imperfectly converted to the Christian faith, but who were actuated by a blind and furious enthusiasm in the cause of their Donatist teachers',
#  'They indignantly supported the exile of their bishops, the demolition of their churches, and the interruption of their secret assemblies',
#  'The violence of the officers of justice, who were usually sustained by a military guard, was sometimes repelled with equal violence, and the blood of some popular ecclesiastics, which had been shed in the quarrel, inflamed their rude followers with an eager desire of revenging the death of these holy martyrs',
#  'By their own cruelty and rashness the ministers of persecution sometimes provoked their fate, and the guilt of an accidental tumult precipitated the criminals into despair and rebellion',
#  'Driven from their native villages, the Donatist peasants assembled in formidable gangs on the edge of the Gaetulian desert, and readily exchanged the habits of labor for a life of idleness and rapine, which was consecrated by the name of religion, and faintly condemned by the doctors of the sect',
#  'The leaders of the Circumcellions assumed the title of captains of the saints; their principal weapon, as they were indifferently provided with swords and spears, was a huge and weighty club, which they termed an \'Israelite\', and the well-known sound of "Praise be to God!"  which they used as their cry of war, diffused consternation over the unarmed provinces of Africa',
#  'At first their depredations were coloured by the plea of necessity, but they soon exceeded the measure of subsistence, indulged without control their intemperance and\n avarice, burnt the villages which they had pillaged, and reigned the licentious tyrants of the open country',
#  'The occupations of husbandry and the administration of justice were interrupted; and, as the Circumcellions pretended to restore the primitive equality of mankind, and to reform the\n abuses of civil society, they opened a secure asylum for the\n slaves and debtors who flocked in crowds to their holy\n standard',
#  'When they were not resisted they usually contented\n themselves with plunder, but the slightest opposition\n provoked them to acts of violence and murder; and some\n catholic priests, who had imprudently signalised their zeal,\n were tortured by the fanatics with the most refined and\n wanton barbarity',
#  'The spirit of the Circumcellions was not\n always exerted against their defenceless enemies; they\n engaged, and sometimes defeated, the troops of the province,\n and in the bloody action of Bagai they attacked in the open\n field, but with unsuccessful valour, an advanced guard of\n the Imperial cavalry',
#  'The Donatists who were taken in arms\n received, and they soon deserved, the same treatment which\n might have been shown to the wild beasts of the desert',
#  'The\n captives died, without a murmur, either by the sword, the\n axe, or the fire; and the measures of retaliation were\n multiplied in a rapid proportion, which aggravated the\n horrors of rebellion and excluded the hope of mutual\n forgiveness',
#  'In the beginning of the present century the\n example of the Circumcellions has been renewed in the\n persecution, the boldness, the crimes and the enthusiasm of\n the Camisards; and if the fanatics of Languedoc surpassed\n those of Numidia by their military achievements, the\n Africans maintained their fierce independence with more\n resolution and perseverance.(159)\n Their religious suicides \nSuch disorders are the natural effects of religious tyranny;\n but the rage of the Donatists was inflamed by a frenzy of a\n very extraordinary kind; and which, if it really prevailed\n among them in so extravagant a degree, cannot surely be\n paralleled in any country or in any age',
#  'Many of these fanatics were possessed with the horror of life, and the desire of martyrdom; and they deemed it of\n little moment by what means, or by what hands, they\n perished, if their conduct was sanctified by the intention\n of devoting themselves to the glory of the true faith, and\n the hope of eternal happiness',
#  '(160) Sometimes they rudely \n disturbed the festivals, and profaned the temples of\n Paganism, with the design of exciting the most zealous of\n the idolaters to revenge the insulted honour of their gods.\n They sometimes forced their way into the courts of justice,\n and compelled the affrighted judge to give orders for their\n immediate execution',
#  'They frequently stopped travellers on\n the public highways, and obliged them to inflict the stroke\n of martyrdom, by the promise of a reward if they consented,\n and by the threat of instant death if they refused to grant\n so very singular a favor',
#  'When they were disappointed of\n every other resource, they announced the day on which, in\n the presence of their friends and brethren, they should cast\n themselves headlong from some lofty rock; and many\n precipices were shown which had acquired fame by the number\n of religious suicides',
#  'In the actions of these desperate\n enthusiasts, who were admired by one party as the martyrs of\n God, and abhorred by the other as the victims of Satan, an\n impartial philosopher may discover the influence and the\n last abuse of that inflexible spirit which was originally\n derived from the character and principals of the Jewish\n nation.\n \n General character of the Christian sects, A.D',
#  '312-361',
#  '\nThe simple narrative of the intestine divisions which\n distracted the peace and dishonoured the triumph of the\n church, will confirm the remark of a Pagan historian, and\n justify the complaint of a venerable bishop',
#  'The experience\n of Ammianus had convinced him that the enmity of the\n Christians towards each other surpassed the fury of savage\n beasts against man; (161) and Gregory Nazianzen most \n pathetically laments that the kingdom of heaven was\n converted by discord into the image of chaos, of a nocturnal\n tempest, and of hell itself',
#  '(162) The fierce and partial \n writers of the times, ascribing all virtue to themselves,\n and imputing all guilt to their adversaries, have painted\n the battle of the angels and daemons',
#  'Our calmer reason will\n reject such pure and perfect monsters of vice or sanctity,\n and will impute an equal, or at least an indiscriminate,\n measure of good and evil to the hostile sectaries, who\n assumed and bestowed the appellations of orthodox and\n heretics',
#  'They had been educated in the same religion and\n the same civil society',
#  'Their hopes and fears in the\n present, or in a future life, were balanced in the same\n proportion',
#  'On either side the error might be innocent, the\n faith sincere, the practice meritorious or corrupt',
#  'Their\n passions were excited by similar objects; and they might\n alternately abuse the favour of the court, or of the people.\n The metaphysical opinions of the Athanasians and the Arians\n could not influence their moral character; and they were\n alike actuated by the intolerant spirit which has been\n extracted from the pure and simple maxims of the Gospel.\n \n Toleration of paganism \nA modern writer, who, with a just confidence, has prefixed\n to his own history the honourable epithets of political and\n philosophical, (163) accuses the timid prudence of \n Montesquieu, for neglecting to enumerate, among the causes\n of the decline of the empire, a law of Constantine, by which\n the exercise of the Pagan worship was absolutely suppressed,\n and a considerable part of his subjects was left destitute\n of priests, temples, and of any public religion',
#  'The zeal of\n the philosophic historian for the rights of mankind has\n induced him to acquiesce in the ambiguous testimony of those\n ecclesiastics who have too lightly ascribed to their\n favourite hero the merit of a general persecution.(164) \n Instead of alleging this imaginary law, which would have\n blazed in the front of the Imperial codes, we may safely\n appeal to the original epistle which Constantine addressed\n to the followers of the ancient religion, at a time when he\n no long disguised his conversion, nor dreaded the rivals of\n his throne',
#  'He invites and exhorts, in the most pressing\n terms, the subjects of the Roman empire to imitate the\n exampleby Constantine, of their master; but he declares that those who still refuse to open their eyes to the celestial light may free enjoy their temples and their fancied gods',
#  'A report\n that the ceremonies of Paganism were suppressed is formally\n contradicted by the emperor himself, who wisely assigns, as\n the principle of his moderation, the invincible force of\n habit, of prejudice, and of superstition',
#  '(165) Without \n violating the sanctity of his promise, without alarming the\n fears of the Pagans, the artful monarch advanced, by slow\n and cautious steps, to undermine the irregular and decayed\n fabric of polytheism',
#  'The partial acts of severity which he\n occasionally exercised, though they were secretly prompted\n by a Christian zeal, were coloured by the fairest pretences\n of justice and the public good; and while Constantine\n designed to ruin the foundations, he seemed to reform the\n abuses, of the ancient religion',
#  'After the example of the\n wisest of his predecessors, he condemned, under the most\n rigorous penalties, the occult and impious arts of\n divination, which excited the vain hopes, and sometimes the\n criminal attempts, of those who were discontented with their\n present condition',
#  'An ignominious silence was imposed on the\n oracles, which had been publicly convicted of fraud and\n falsehood; the effeminate priests of the Nile were\n abolished; and Constantine discharged the duties of a Roman\n censor, when he gave orders for the demolition of several\n temples of Phoenicia, in which every mode of prostitution\n was devoutly practised in the face of day, and to the honour\n of Venus.(166) The Imperial city of Constantinople was, in \n some measure, raised at the expense, and was adorned with\n the spoils, of the opulent temples of Greece and Asia; the\n sacred property; was confiscated; the statues of gods and\n heroes were transported, with rude familiarity, among a\n people who considered them as objects, not of adoration, but\n of curiosity; the gold and silver were restored to\n circulation; and the magistrates, the bishops, and the\n eunuchs, improved the fortunate occasion of gratifying, at\n once, their zeal, their avarice, and their resentment',
#  'But\n these depredations were confined to a small part of the\n Roman world; and the provinces had been long since\n accustomed to endure the same sacrilegious rapine, from the\n tyranny of princes and proconsuls who could not be suspected\n of any design to subvert the established religion.(167)\n and his sons',
#  '\n The sons of Constantine trod in the footsteps of their\n father with more zeal and with less discretion',
#  'The\n pretences of rapine and oppression were insensibly multiplied (168); every indulgence was shown to the illegal behaviour of the Christians; every doubt was explained to the disadvantage of Paganism, and the demolition of the temples was celebrated as one of the auspicious events of the reign of Constans and Constantius',
#  '(169) The name of Constantius is prefixed to a concise law, which might have superseded the necessity of any future prohibitions',
#  '  But there is the  strongest reason to believe that this formidable edict was either composed without being published, or was published without being executed',
#  'The evidence of facts, and the monuments which are still extant of brass and marble, continue to prove the public exercise of the Pagan worship during the whole reign of the sons of Constantine',
#  'In the East as well as in the West, in cities as well as in the country, a great number of temples were respected, or at least were spared; and the devout multitude still enjoyed the luxury of sacrifices, of festivals, and of processions, by the permission, or by the connivance, of the civil government',
#  'About four years after the supposed date of his bloody edict, Constantius visited the temples of Rome; and the decency of his behaviour is recommended by a Pagan orator as an example worthy of the imitation of succeeding princes',
#  ' The senate still presumed to consecrate, by solemn decrees, the divine\n memory of their sovereigns; and Constantine himself was associated, after death, to those gods whom he had renounced and insulted during his life',
#  'The title, the ensigns, the prerogatives, of SOVEREIGN PONTIFF, which had been instituted by Numa, and assumed by Augustus, were accepted, without hesitation, by seven Christian emperors, who were invested with a more absolute authority over the religion which they had deserted than over that which they professed',
#  '(172)\n  The divisions of Christianity suspended the ruin of Paganism; (173) and the holy war against the infidels was less vigorously prosecuted by princes and bishops who were more immediately alarmed by the guilt and danger of domestic rebellion',
#  'The extirpation of idolatry (174) might have been justified by the established principles of intolerance: but the hostile sects, which alternately reigned in the Imperial court, were mutually apprehensive of alienating, and perhaps exasperating, the minds of a powerful, though declining faction',
#  'Every motive of authority and fashion, of interest and reason, now militated on the side of Christianity; but two or three generations elapsed before their victorious influence was universally felt',
#  'The religion which had so long and so lately been established in the Roman empire was still revered by a numerous people, less attached indeed to speculative opinion than to ancient custom',
#  'The honours of the state and army were indifferently bestowed on all the subjects of Constantine and Constantius; and a considerable portion of knowledge and wealth and valour was still engaged in the service of polytheism',
#  'The superstition of the senator and of the peasant, of the poet and the philosopher, was derived from very different causes, but they met with equal devotion in the temples of the gods',
#  'Their zeal was insensibly provoked by the insulting triumph of a proscribed sect; and their hopes we revived by the well-grounded confidence that the presumptive heir of the empire, a young and valiant hero, who had delivered Gaul from the arms of the barbarians, had secretly embraced the religion of his ancestors.']

# %%
#we can use list indexing to grab a sentence at a time 
#creating a Doc can take some time, so let's start with a test sentence 
test= chap21_sents[21]   

test

#pulling a random sentence
# Out:
# 'That divided church was incapable of affording\n an impartial judicature; the controversy was solemnly tried\n in five successive tribunals, which were appointed by the\n emperor; and the whole proceeding, from the first appeal to\n the final sentence, lasted above three years'

# %%
doc = nlp(test)

# %%
 #stanza's output is something called a Doc 
#lets see what the output looks like 
doc
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "That",
#       "lemma": "that",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Number=Sing|PronType=Dem",
#       "head": 3,
#       "deprel": "det",
#       "misc": "",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "divided",
#       "lemma": "divide",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 3,
#       "deprel": "amod",
#       "misc": "",
#       "start_char": 5,
#       "end_char": 12,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "church",
#       "lemma": "church",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "nsubj",
#       "misc": "",
#       "start_char": 13,
#       "end_char": 19,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 5,
#       "deprel": "cop",
#       "misc": "",
#       "start_char": 20,
#       "end_char": 23,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "incapable",
#       "lemma": "incapable",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 0,
#       "deprel": "root",
#       "misc": "",
#       "start_char": 24,
#       "end_char": 33,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 7,
#       "deprel": "case",
#       "misc": "",
#       "start_char": 34,
#       "end_char": 36,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "affording",
#       "lemma": "affording",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "obl",
#       "misc": "",
#       "start_char": 37,
#       "end_char": 46,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "an",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 3,
#       "deprel": "det",
#       "misc": "",
#       "start_char": 47,
#       "end_char": 49,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "impartial",
#       "lemma": "impartial",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 3,
#       "deprel": "amod",
#       "misc": "",
#       "start_char": 50,
#       "end_char": 59,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "judicature;",
#       "lemma": "judicature;",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "nsubj:pass",
#       "misc": "",
#       "start_char": 60,
#       "end_char": 71,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 5,
#       "deprel": "det",
#       "misc": "",
#       "start_char": 72,
#       "end_char": 75,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "controversy",
#       "lemma": "controversy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "nsubj:pass",
#       "misc": "",
#       "start_char": 76,
#       "end_char": 87,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 8,
#       "deprel": "aux:pass",
#       "misc": "",
#       "start_char": 88,
#       "end_char": 91,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "solemnly",
#       "lemma": "solemnly",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 8,
#       "deprel": "advmod",
#       "misc": "",
#       "start_char": 92,
#       "end_char": 100,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "tried",
#       "lemma": "try",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "",
#       "start_char": 101,
#       "end_char": 106,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 4,
#       "deprel": "case",
#       "misc": "",
#       "start_char": 107,
#       "end_char": 109,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "five",
#       "lemma": "five",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 4,
#       "deprel": "nummod",
#       "misc": "",
#       "start_char": 110,
#       "end_char": 114,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "successive",
#       "lemma": "successive",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 4,
#       "deprel": "amod",
#       "misc": "",
#       "start_char": 115,
#       "end_char": 125,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "tribunals,",
#       "lemma": "tribunals,",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "",
#       "start_char": 126,
#       "end_char": 136,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "which",
#       "lemma": "which",
#       "upos": "PRON",
#       "xpos": "WDT",
#       "feats": "PronType=Rel",
#       "head": 7,
#       "deprel": "nsubj:pass",
#       "misc": "",
#       "start_char": 137,
#       "end_char": 142,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 7,
#       "deprel": "aux:pass",
#       "misc": "",
#       "start_char": 143,
#       "end_char": 147,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "appointed",
#       "lemma": "appoint",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 4,
#       "deprel": "acl:relcl",
#       "misc": "",
#       "start_char": 148,
#       "end_char": 157,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "by",
#       "lemma": "by",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 9,
#       "deprel": "case",
#       "misc": "",
#       "start_char": 158,
#       "end_char": 160,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 7,
#       "deprel": "obl:agent",
#       "misc": "",
#       "start_char": 161,
#       "end_char": 164,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "emperor;",
#       "lemma": "emperor;",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "",
#       "start_char": 165,
#       "end_char": 173,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 5,
#       "deprel": "cc",
#       "misc": "",
#       "start_char": 174,
#       "end_char": 177,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 5,
#       "deprel": "det",
#       "misc": "",
#       "start_char": 178,
#       "end_char": 181,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "whole",
#       "lemma": "whole",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 5,
#       "deprel": "amod",
#       "misc": "",
#       "start_char": 182,
#       "end_char": 187,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "proceeding,",
#       "lemma": "proceeding,",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "conj",
#       "misc": "",
#       "start_char": 188,
#       "end_char": 199,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "from",
#       "lemma": "from",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 9,
#       "deprel": "case",
#       "misc": "",
#       "start_char": 200,
#       "end_char": 204,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 9,
#       "deprel": "det",
#       "misc": "",
#       "start_char": 205,
#       "end_char": 208,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "first",
#       "lemma": "first",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos|NumType=Ord",
#       "head": 9,
#       "deprel": "amod",
#       "misc": "",
#       "start_char": 209,
#       "end_char": 214,
#       "ner": "S-ORDINAL",
#       "multi_ner": [
#         "S-ORDINAL"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "appeal",
#       "lemma": "appeal",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "nmod",
#       "misc": "",
#       "start_char": 215,
#       "end_char": 221,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 9,
#       "deprel": "nmod",
#       "misc": "",
#       "start_char": 222,
#       "end_char": 224,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 3,
#       "deprel": "det",
#       "misc": "",
#       "start_char": 225,
#       "end_char": 228,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "final",
#       "lemma": "final",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 3,
#       "deprel": "amod",
#       "misc": "",
#       "start_char": 229,
#       "end_char": 234,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "sentence,",
#       "lemma": "sentence,",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "nsubj",
#       "misc": "",
#       "start_char": 235,
#       "end_char": 244,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "lasted",
#       "lemma": "last",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "",
#       "start_char": 245,
#       "end_char": 251,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "above",
#       "lemma": "above",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 7,
#       "deprel": "case",
#       "misc": "",
#       "start_char": 252,
#       "end_char": 257,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "three",
#       "lemma": "three",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 7,
#       "deprel": "nummod",
#       "misc": "",
#       "start_char": 258,
#       "end_char": 263,
#       "ner": "B-DATE",
#       "multi_ner": [
#         "B-DATE"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "years",
#       "lemma": "year",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 4,
#       "deprel": "obl",
#       "misc": "",
#       "start_char": 264,
#       "end_char": 269,
#       "ner": "E-DATE",
#       "multi_ner": [
#         "E-DATE"
#       ]
#     }
#   ]
# ]

# %%
#lets see what type this is 
type(doc)
# Out:
# stanza.models.common.doc.Document

# %%
##take 5-10 minutes and go to the stanza documentation I have linked above
#in a group, write code to access the text, pos, ner, and upos compontents of our tokens
print(*[f'word:  {word.pos}\tpos: {word.text}\tupos:  {word.upos}\txpos:  {word.xpos}\tfeats: {word.feats if word.feats else "_"}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# word:  DET	pos: That	upos:  DET	xpos:  DT	feats: Number=Sing|PronType=Dem
# word:  VERB	pos: divided	upos:  VERB	xpos:  VBN	feats: Tense=Past|VerbForm=Part
# word:  NOUN	pos: church	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  AUX	pos: was	upos:  AUX	xpos:  VBD	feats: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# word:  ADJ	pos: incapable	upos:  ADJ	xpos:  JJ	feats: Degree=Pos
# word:  ADP	pos: of	upos:  ADP	xpos:  IN	feats: _
# word:  NOUN	pos: affording	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  DET	pos: an	upos:  DET	xpos:  DT	feats: Definite=Ind|PronType=Art
# word:  ADJ	pos: impartial	upos:  ADJ	xpos:  JJ	feats: Degree=Pos
# word:  NOUN	pos: judicature;	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  DET	pos: the	upos:  DET	xpos:  DT	feats: Definite=Def|PronType=Art
# word:  NOUN	pos: controversy	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  AUX	pos: was	upos:  AUX	xpos:  VBD	feats: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# word:  ADV	pos: solemnly	upos:  ADV	xpos:  RB	feats: _
# word:  VERB	pos: tried	upos:  VERB	xpos:  VBN	feats: Tense=Past|VerbForm=Part|Voice=Pass
# word:  ADP	pos: in	upos:  ADP	xpos:  IN	feats: _
# word:  NUM	pos: five	upos:  NUM	xpos:  CD	feats: NumForm=Word|NumType=Card
# word:  ADJ	pos: successive	upos:  ADJ	xpos:  JJ	feats: Degree=Pos
# word:  NOUN	pos: tribunals,	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  PRON	pos: which	upos:  PRON	xpos:  WDT	feats: PronType=Rel
# word:  AUX	pos: were	upos:  AUX	xpos:  VBD	feats: Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# word:  VERB	pos: appointed	upos:  VERB	xpos:  VBN	feats: Tense=Past|VerbForm=Part|Voice=Pass
# word:  ADP	pos: by	upos:  ADP	xpos:  IN	feats: _
# word:  DET	pos: the	upos:  DET	xpos:  DT	feats: Definite=Def|PronType=Art
# word:  NOUN	pos: emperor;	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  CCONJ	pos: and	upos:  CCONJ	xpos:  CC	feats: _
# word:  DET	pos: the	upos:  DET	xpos:  DT	feats: Definite=Def|PronType=Art
# word:  ADJ	pos: whole	upos:  ADJ	xpos:  JJ	feats: Degree=Pos
# word:  NOUN	pos: proceeding,	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  ADP	pos: from	upos:  ADP	xpos:  IN	feats: _
# word:  DET	pos: the	upos:  DET	xpos:  DT	feats: Definite=Def|PronType=Art
# word:  ADJ	pos: first	upos:  ADJ	xpos:  JJ	feats: Degree=Pos|NumType=Ord
# word:  NOUN	pos: appeal	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  ADP	pos: to	upos:  ADP	xpos:  IN	feats: _
# word:  DET	pos: the	upos:  DET	xpos:  DT	feats: Definite=Def|PronType=Art
# word:  ADJ	pos: final	upos:  ADJ	xpos:  JJ	feats: Degree=Pos
# word:  NOUN	pos: sentence,	upos:  NOUN	xpos:  NN	feats: Number=Sing
# word:  VERB	pos: lasted	upos:  VERB	xpos:  VBD	feats: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# word:  ADP	pos: above	upos:  ADP	xpos:  IN	feats: _
# word:  NUM	pos: three	upos:  NUM	xpos:  CD	feats: NumForm=Word|NumType=Card
# word:  NOUN	pos: years	upos:  NOUN	xpos:  NNS	feats: Number=Plur

# %%
#next, look at the stanza documentation and print the named entities for our document 
print(doc.entities)
# Out:
# [{
#   "text": "five",
#   "type": "CARDINAL",
#   "start_char": 110,
#   "end_char": 114
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 209,
#   "end_char": 214
# }, {
#   "text": "three years",
#   "type": "DATE",
#   "start_char": 258,
#   "end_char": 269
# }]

# %% [markdown]
# **NER and processing multiple documents**

# %%
# load a new pipeline with just the NER processor 
nlp_ner= stanza.Pipeline(lang='en', processors='tokenize, ner',tokenize_pretokenized=True)
#pretokenized= True is still included, since we are going to give the processor our large list of sentences
# Out:
# 2023-10-25 15:41:15 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2023-10-25 15:41:16 INFO: Loading these models for language: en (English):
# ================================
# | Processor | Package          |
# --------------------------------
# | tokenize  | combined         |
# | ner       | ontonotes_charlm |
# ================================
#
# 2023-10-25 15:41:16 INFO: Using device: cpu
# 2023-10-25 15:41:16 INFO: Loading: tokenize
# 2023-10-25 15:41:16 INFO: Loading: ner
# 2023-10-25 15:41:17 INFO: Done loading processors!

# %%
#this is a solution for our prior output issue-- still takes a bit to run though 
# Note! Can only be done with text that has already been tokenized into sentences
#this allows us to parallel process multiple sentences at a time
Gibbon_docs_chap21sents = [stanza.Document([], text=d) for d in chap21_sents]
Gibbon_out_docs = nlp_ner(Gibbon_docs_chap21sents) 
print(Gibbon_out_docs[1])
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Constantine",
#       "misc": "",
#       "start_char": 0,
#       "end_char": 11,
#       "ner": "S-PERSON",
#       "multi_ner": [
#         "S-PERSON"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "gave",
#       "misc": "",
#       "start_char": 12,
#       "end_char": 16,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "them",
#       "misc": "",
#       "start_char": 17,
#       "end_char": 21,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "security,",
#       "misc": "",
#       "start_char": 22,
#       "end_char": 31,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "wealth,",
#       "misc": "",
#       "start_char": 32,
#       "end_char": 39,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "honours,",
#       "misc": "",
#       "start_char": 40,
#       "end_char": 48,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "and",
#       "misc": "",
#       "start_char": 49,
#       "end_char": 52,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "revenge;",
#       "misc": "",
#       "start_char": 53,
#       "end_char": 61,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "and",
#       "misc": "",
#       "start_char": 62,
#       "end_char": 65,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "the",
#       "misc": "",
#       "start_char": 66,
#       "end_char": 69,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "support",
#       "misc": "",
#       "start_char": 70,
#       "end_char": 77,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "of",
#       "misc": "",
#       "start_char": 78,
#       "end_char": 80,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "the",
#       "misc": "",
#       "start_char": 81,
#       "end_char": 84,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "orthodox",
#       "misc": "",
#       "start_char": 85,
#       "end_char": 93,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "faith",
#       "misc": "",
#       "start_char": 94,
#       "end_char": 99,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "was",
#       "misc": "",
#       "start_char": 100,
#       "end_char": 103,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "considered",
#       "misc": "",
#       "start_char": 104,
#       "end_char": 114,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "as",
#       "misc": "",
#       "start_char": 115,
#       "end_char": 117,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "the",
#       "misc": "",
#       "start_char": 118,
#       "end_char": 121,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "most",
#       "misc": "",
#       "start_char": 122,
#       "end_char": 126,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "sacred",
#       "misc": "",
#       "start_char": 127,
#       "end_char": 133,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "and",
#       "misc": "",
#       "start_char": 134,
#       "end_char": 137,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 23,
#       "text": "important",
#       "misc": "",
#       "start_char": 138,
#       "end_char": 147,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "duty",
#       "misc": "",
#       "start_char": 148,
#       "end_char": 152,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "of",
#       "misc": "",
#       "start_char": 153,
#       "end_char": 155,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "the",
#       "misc": "",
#       "start_char": 156,
#       "end_char": 159,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "civil",
#       "misc": "",
#       "start_char": 160,
#       "end_char": 165,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "magistrate",
#       "misc": "",
#       "start_char": 166,
#       "end_char": 176,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ]

# %%
#how we access the named entities from our documents list 
for doc in Gibbon_out_docs:
    print(doc.ents)
# Out:
# [{
#   "text": "The Schism of the Donatists",
#   "type": "WORK_OF_ART",
#   "start_char": 24,
#   "end_char": 51
# }, {
#   "text": "The Arian Controversy — Athanasius — Distracted state of the Church and the Empire under Constantine",
#   "type": "WORK_OF_ART",
#   "start_char": 54,
#   "end_char": 154
# }, {
#   "text": "Toleration of Paganism",
#   "type": "WORK_OF_ART",
#   "start_char": 170,
#   "end_char": 192
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# [{
#   "text": "Milan,",
#   "type": "GPE",
#   "start_char": 13,
#   "end_char": 19
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 98
# }]
# [{
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 164,
#   "end_char": 172
# }, {
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 227,
#   "end_char": 239
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# []
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 94,
#   "end_char": 98
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 231,
#   "end_char": 242
# }, {
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 377,
#   "end_char": 385
# }]
# [{
#   "text": "Paul of Samosata; the Montanists of Phrygia,",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 139
# }, {
#   "text": "Novatians,",
#   "type": "NORP",
#   "start_char": 199,
#   "end_char": 209
# }, {
#   "text": "Marcionites",
#   "type": "NORP",
#   "start_char": 272,
#   "end_char": 283
# }, {
#   "text": "Valentinians,",
#   "type": "NORP",
#   "start_char": 288,
#   "end_char": 301
# }, {
#   "text": "Gnostics",
#   "type": "NORP",
#   "start_char": 342,
#   "end_char": 350
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 354,
#   "end_char": 358
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 363,
#   "end_char": 368
# }, {
#   "text": "Manichaeans,",
#   "type": "NORP",
#   "start_char": 409,
#   "end_char": 421
# }, {
#   "text": "Persia",
#   "type": "GPE",
#   "start_char": 453,
#   "end_char": 459
# }, {
#   "text": "Oriental",
#   "type": "NORP",
#   "start_char": 489,
#   "end_char": 497
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 502,
#   "end_char": 511
# }]
# [{
#   "text": "Diocletian;",
#   "type": "PERSON",
#   "start_char": 61,
#   "end_char": 72
# }]
# [{
#   "text": "Two",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 86
# }]
# [{
#   "text": "Manichaeans",
#   "type": "NORP",
#   "start_char": 24,
#   "end_char": 35
# }]
# []
# [{
#   "text": "Novatians,",
#   "type": "NORP",
#   "start_char": 121,
#   "end_char": 131
# }]
# [{
#   "text": "Constantinople;",
#   "type": "GPE",
#   "start_char": 116,
#   "end_char": 131
# }, {
#   "text": "Acesius,",
#   "type": "PERSON",
#   "start_char": 194,
#   "end_char": 202
# }, {
#   "text": "Nice;",
#   "type": "PERSON",
#   "start_char": 221,
#   "end_char": 226
# }, {
#   "text": "African",
#   "type": "NORP",
#   "start_char": 390,
#   "end_char": 397
# }]
# [{
#   "text": "312",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }]
# [{
#   "text": "Constantine,",
#   "type": "PERSON",
#   "start_char": 67,
#   "end_char": 79
# }, {
#   "text": "Maxentius",
#   "type": "PERSON",
#   "start_char": 104,
#   "end_char": 113
# }, {
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 128,
#   "end_char": 134
# }]
# [{
#   "text": "the Columns of Hercules,",
#   "type": "ORG",
#   "start_char": 98,
#   "end_char": 122
# }, {
#   "text": "Carthage,",
#   "type": "GPE",
#   "start_char": 245,
#   "end_char": 254
# }, {
#   "text": "second",
#   "type": "ORDINAL",
#   "start_char": 259,
#   "end_char": 265
# }, {
#   "text": "West Caecilian",
#   "type": "GPE",
#   "start_char": 324,
#   "end_char": 338
# }, {
#   "text": "Majourinus",
#   "type": "ORG",
#   "start_char": 343,
#   "end_char": 353
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 363,
#   "end_char": 366
# }]
# [{
#   "text": "Cacilian",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 28
# }, {
#   "text": "Numidia",
#   "type": "GPE",
#   "start_char": 217,
#   "end_char": 224
# }]
# [{
#   "text": "Caecilian,",
#   "type": "PERSON",
#   "start_char": 73,
#   "end_char": 83
# }, {
#   "text": "Majorinus,",
#   "type": "PERSON",
#   "start_char": 100,
#   "end_char": 110
# }, {
#   "text": "Numidian",
#   "type": "NORP",
#   "start_char": 287,
#   "end_char": 295
# }]
# [{
#   "text": "the Holy Scriptures",
#   "type": "PERSON",
#   "start_char": 185,
#   "end_char": 204
# }, {
#   "text": "Diocletian",
#   "type": "PERSON",
#   "start_char": 224,
#   "end_char": 234
# }]
# [{
#   "text": "African",
#   "type": "NORP",
#   "start_char": 197,
#   "end_char": 204
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 205,
#   "end_char": 215
# }]
# [{
#   "text": "five",
#   "type": "CARDINAL",
#   "start_char": 110,
#   "end_char": 114
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 209,
#   "end_char": 214
# }, {
#   "text": "three years",
#   "type": "DATE",
#   "start_char": 258,
#   "end_char": 269
# }]
# [{
#   "text": "Africa,",
#   "type": "GPE",
#   "start_char": 83,
#   "end_char": 90
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 105,
#   "end_char": 108
# }, {
#   "text": "Rome",
#   "type": "GPE",
#   "start_char": 190,
#   "end_char": 194
# }, {
#   "text": "Arles,",
#   "type": "PERSON",
#   "start_char": 202,
#   "end_char": 208
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 237,
#   "end_char": 248
# }, {
#   "text": "Caecilian;",
#   "type": "PERSON",
#   "start_char": 320,
#   "end_char": 330
# }, {
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 440,
#   "end_char": 446
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 119,
#   "end_char": 130
# }, {
#   "text": "Donatist",
#   "type": "ORG",
#   "start_char": 217,
#   "end_char": 225
# }]
# [{
#   "text": "Osius",
#   "type": "PERSON",
#   "start_char": 225,
#   "end_char": 230
# }]
# []
# [{
#   "text": "Schism of the Donatists, A.D",
#   "type": "PERSON",
#   "start_char": 202,
#   "end_char": 230
# }]
# [{
#   "text": "315",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }]
# [{
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 154,
#   "end_char": 160
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 167,
#   "end_char": 172
# }, {
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 219,
#   "end_char": 231
# }]
# [{
#   "text": "Donatists",
#   "type": "NORP",
#   "start_char": 59,
#   "end_char": 68
# }]
# [{
#   "text": "Caecilian,",
#   "type": "PERSON",
#   "start_char": 145,
#   "end_char": 155
# }, {
#   "text": "Europe",
#   "type": "LOC",
#   "start_char": 357,
#   "end_char": 363
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 368,
#   "end_char": 372
# }, {
#   "text": "African",
#   "type": "NORP",
#   "start_char": 517,
#   "end_char": 524
# }]
# []
# [{
#   "text": "East,",
#   "type": "NORP",
#   "start_char": 75,
#   "end_char": 80
# }]
# []
# [{
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 69,
#   "end_char": 77
# }]
# [{
#   "text": "the Holy Eucharist",
#   "type": "PERSON",
#   "start_char": 130,
#   "end_char": 148
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 323,
#   "end_char": 326
# }, {
#   "text": "Africa,",
#   "type": "GPE",
#   "start_char": 386,
#   "end_char": 393
# }, {
#   "text": "Donatists",
#   "type": "NORP",
#   "start_char": 554,
#   "end_char": 563
# }, {
#   "text": "Numidia,",
#   "type": "GPE",
#   "start_char": 616,
#   "end_char": 624
# }, {
#   "text": "four",
#   "type": "CARDINAL",
#   "start_char": 653,
#   "end_char": 657
# }, {
#   "text": "hundred",
#   "type": "CARDINAL",
#   "start_char": 658,
#   "end_char": 665
# }]
# []
# [{
#   "text": "fourth",
#   "type": "ORDINAL",
#   "start_char": 2,
#   "end_char": 8
# }, {
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 21,
#   "end_char": 29
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 41,
#   "end_char": 46
# }, {
#   "text": "Rogatians",
#   "type": "NORP",
#   "start_char": 160,
#   "end_char": 169
# }, {
#   "text": "the Caesarean Mauritania.(10)",
#   "type": "LOC",
#   "start_char": 330,
#   "end_char": 359
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 364,
#   "end_char": 375
# }]
# [{
#   "text": "Donatists",
#   "type": "NORP",
#   "start_char": 18,
#   "end_char": 27
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 87,
#   "end_char": 98
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 158,
#   "end_char": 167
# }]
# []
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 27
# }, {
#   "text": "Clovis",
#   "type": "PERSON",
#   "start_char": 39,
#   "end_char": 45
# }, {
#   "text": "Theodoric,",
#   "type": "PERSON",
#   "start_char": 50,
#   "end_char": 60
# }, {
#   "text": "Romans",
#   "type": "NORP",
#   "start_char": 96,
#   "end_char": 102
# }, {
#   "text": "Arianism",
#   "type": "NORP",
#   "start_char": 170,
#   "end_char": 178
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 182,
#   "end_char": 187
# }, {
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 241,
#   "end_char": 246
# }]
# [{
#   "text": "Christ 360",
#   "type": "PERSON",
#   "start_char": 7,
#   "end_char": 17
# }]
# [{
#   "text": "Plato,",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 20
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 66,
#   "end_char": 71
# }, {
#   "text": "Athenian",
#   "type": "NORP",
#   "start_char": 124,
#   "end_char": 132
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 136,
#   "end_char": 141
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 214,
#   "end_char": 219
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 91,
#   "end_char": 96
# }, {
#   "text": "Platonic",
#   "type": "NORP",
#   "start_char": 153,
#   "end_char": 161
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 172,
#   "end_char": 177
# }, {
#   "text": "Logos",
#   "type": "ORG",
#   "start_char": 257,
#   "end_char": 262
# }, {
#   "text": "the Son of an Eternal",
#   "type": "PERSON",
#   "start_char": 330,
#   "end_char": 351
# }]
# [{
#   "text": "Academy;",
#   "type": "NORP",
#   "start_char": 100,
#   "end_char": 108
# }, {
#   "text": "Plato,",
#   "type": "PERSON",
#   "start_char": 162,
#   "end_char": 168
# }, {
#   "text": "thirty years.(12)",
#   "type": "DATE",
#   "start_char": 236,
#   "end_char": 253
# }, {
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 277,
#   "end_char": 287
# }]
# [{
#   "text": "Christ 300",
#   "type": "PERSON",
#   "start_char": 7,
#   "end_char": 17
# }]
# [{
#   "text": "Macedonians",
#   "type": "NORP",
#   "start_char": 16,
#   "end_char": 27
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 42,
#   "end_char": 46
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 51,
#   "end_char": 56
# }, {
#   "text": "Greece;",
#   "type": "LANGUAGE",
#   "start_char": 86,
#   "end_char": 93
# }, {
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 124,
#   "end_char": 129
# }, {
#   "text": "Alexandria.",
#   "type": "GPE",
#   "start_char": 225,
#   "end_char": 236
# }, {
#   "text": "Jews",
#   "type": "NORP",
#   "start_char": 263,
#   "end_char": 267
# }, {
#   "text": "Hebrews",
#   "type": "NORP",
#   "start_char": 472,
#   "end_char": 479
# }]
# [{
#   "text": "Athenian",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 101
# }]
# [{
#   "text": "Egyptian",
#   "type": "NORP",
#   "start_char": 230,
#   "end_char": 238
# }]
# [{
#   "text": "One hundred years before",
#   "type": "DATE",
#   "start_char": 0,
#   "end_char": 24
# }, {
#   "text": "Christ,",
#   "type": "PERSON",
#   "start_char": 38,
#   "end_char": 45
# }, {
#   "text": "Alexandrian",
#   "type": "NORP",
#   "start_char": 166,
#   "end_char": 177
# }, {
#   "text": "Solomon",
#   "type": "PERSON",
#   "start_char": 267,
#   "end_char": 274
# }]
# [{
#   "text": "Mosaic",
#   "type": "NORP",
#   "start_char": 28,
#   "end_char": 34
# }, {
#   "text": "Grecian",
#   "type": "NORP",
#   "start_char": 49,
#   "end_char": 56
# }, {
#   "text": "Philo,",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 101
# }, {
#   "text": "Hebrews;",
#   "type": "PERSON",
#   "start_char": 243,
#   "end_char": 251
# }, {
#   "text": "the Logos to the Jehovah of Moses",
#   "type": "WORK_OF_ART",
#   "start_char": 286,
#   "end_char": 319
# }, {
#   "text": "the Son of God",
#   "type": "PERSON",
#   "start_char": 344,
#   "end_char": 358
# }, {
#   "text": "the Apostle St John, A.D",
#   "type": "PERSON",
#   "start_char": 558,
#   "end_char": 582
# }]
# [{
#   "text": "97",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 2
# }]
# [{
#   "text": "Plato,",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 23
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 76,
#   "end_char": 87
# }, {
#   "text": "Jews",
#   "type": "NORP",
#   "start_char": 111,
#   "end_char": 115
# }]
# [{
#   "text": "Deity,",
#   "type": "PERSON",
#   "start_char": 39,
#   "end_char": 45
# }, {
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 130,
#   "end_char": 135
# }, {
#   "text": "Academy, the Porch,",
#   "type": "PERSON",
#   "start_char": 210,
#   "end_char": 229
# }, {
#   "text": "Logos",
#   "type": "ORG",
#   "start_char": 287,
#   "end_char": 292
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 9,
#   "end_char": 18
# }, {
#   "text": "Nerva,",
#   "type": "PERSON",
#   "start_char": 72,
#   "end_char": 78
# }, {
#   "text": "Jesus of Nazareth;",
#   "type": "PERSON",
#   "start_char": 283,
#   "end_char": 301
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 227,
#   "end_char": 230
# }, {
#   "text": "Ebionites",
#   "type": "PERSON",
#   "start_char": 309,
#   "end_char": 318
# }, {
#   "text": "Docetes",
#   "type": "ORG",
#   "start_char": 323,
#   "end_char": 330
# }]
# [{
#   "text": "Nazarenes,(23)",
#   "type": "PERSON",
#   "start_char": 48,
#   "end_char": 62
# }]
# [{
#   "text": "Jesus",
#   "type": "PERSON",
#   "start_char": 13,
#   "end_char": 18
# }]
# [{
#   "text": "Hewbrew",
#   "type": "NORP",
#   "start_char": 79,
#   "end_char": 86
# }, {
#   "text": "Son of God,",
#   "type": "PERSON",
#   "start_char": 330,
#   "end_char": 341
# }]
# [{
#   "text": "John",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 4
# }]
# [{
#   "text": "About fifty years",
#   "type": "DATE",
#   "start_char": 0,
#   "end_char": 17
# }, {
#   "text": "Ebionites,",
#   "type": "NORP",
#   "start_char": 34,
#   "end_char": 44
# }, {
#   "text": "Justin Martyr,",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 89
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 185,
#   "end_char": 194
# }]
# []
# [{
#   "text": "Gnostics,",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 13
# }]
# [{
#   "text": "Plato,",
#   "type": "GPE",
#   "start_char": 26,
#   "end_char": 32
# }, {
#   "text": "Aeon,",
#   "type": "PERSON",
#   "start_char": 120,
#   "end_char": 125
# }, {
#   "text": "Emanation of the Deity,",
#   "type": "PERSON",
#   "start_char": 129,
#   "end_char": 152
# }]
# [{
#   "text": "Mount Calvary,",
#   "type": "LOC",
#   "start_char": 40,
#   "end_char": 54
# }, {
#   "text": "Virgin,(27)",
#   "type": "PERSON",
#   "start_char": 162,
#   "end_char": 173
# }, {
#   "text": "Jordan",
#   "type": "GPE",
#   "start_char": 211,
#   "end_char": 217
# }, {
#   "text": "Pilate",
#   "type": "PERSON",
#   "start_char": 347,
#   "end_char": 353
# }, {
#   "text": "three days,",
#   "type": "DATE",
#   "start_char": 451,
#   "end_char": 462
# }, {
#   "text": "Mysterious nature of the Trinity",
#   "type": "PERSON",
#   "start_char": 490,
#   "end_char": 522
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 99,
#   "end_char": 104
# }, {
#   "text": "the second and third centuries",
#   "type": "DATE",
#   "start_char": 142,
#   "end_char": 172
# }, {
#   "text": "Athenian",
#   "type": "NORP",
#   "start_char": 213,
#   "end_char": 221
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 312,
#   "end_char": 321
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 24,
#   "end_char": 29
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 119,
#   "end_char": 124
# }, {
#   "text": "Trinity,(31)",
#   "type": "PERSON",
#   "start_char": 168,
#   "end_char": 180
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 227,
#   "end_char": 236
# }, {
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 248,
#   "end_char": 258
# }]
# []
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 30,
#   "end_char": 39
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 63,
#   "end_char": 73
# }, {
#   "text": "the divinity of the Logos,",
#   "type": "PERSON",
#   "start_char": 169,
#   "end_char": 195
# }]
# []
# []
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 174,
#   "end_char": 177
# }, {
#   "text": "Platonic",
#   "type": "NORP",
#   "start_char": 297,
#   "end_char": 305
# }, {
#   "text": "Zeal of the Christians.",
#   "type": "PERSON",
#   "start_char": 314,
#   "end_char": 337
# }]
# [{
#   "text": "Athens",
#   "type": "GPE",
#   "start_char": 153,
#   "end_char": 159
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 178,
#   "end_char": 189
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 442,
#   "end_char": 447
# }]
# [{
#   "text": "Tertullian",
#   "type": "PERSON",
#   "start_char": 240,
#   "end_char": 250
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 263,
#   "end_char": 272
# }, {
#   "text": "Grecian",
#   "type": "NORP",
#   "start_char": 353,
#   "end_char": 360
# }]
# []
# []
# []
# [{
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 68,
#   "end_char": 73
# }]
# [{
#   "text": "Son",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 20
# }, {
#   "text": "the Son of an eternal",
#   "type": "PERSON",
#   "start_char": 320,
#   "end_char": 341
# }]
# [{
#   "text": "Christ,",
#   "type": "PERSON",
#   "start_char": 36,
#   "end_char": 43
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 48,
#   "end_char": 58
# }, {
#   "text": "Bithynia",
#   "type": "GPE",
#   "start_char": 62,
#   "end_char": 70
# }, {
#   "text": "Pliny",
#   "type": "PERSON",
#   "start_char": 103,
#   "end_char": 108
# }, {
#   "text": "Christ,",
#   "type": "PERSON",
#   "start_char": 316,
#   "end_char": 323
# }, {
#   "text": "Father of Christ,",
#   "type": "PERSON",
#   "start_char": 628,
#   "end_char": 645
# }]
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 58,
#   "end_char": 68
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 228,
#   "end_char": 233
# }]
# []
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 36,
#   "end_char": 41
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 79,
#   "end_char": 89
# }, {
#   "text": "Platonists:",
#   "type": "NORP",
#   "start_char": 99,
#   "end_char": 110
# }, {
#   "text": "second",
#   "type": "ORDINAL",
#   "start_char": 115,
#   "end_char": 121
# }]
# []
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 8,
#   "end_char": 18
# }]
# []
# []
# [{
#   "text": "Platonic",
#   "type": "NORP",
#   "start_char": 107,
#   "end_char": 115
# }]
# [{
#   "text": "Praxeas",
#   "type": "GPE",
#   "start_char": 32,
#   "end_char": 39
# }, {
#   "text": "Sabellius",
#   "type": "PERSON",
#   "start_char": 44,
#   "end_char": 53
# }, {
#   "text": "the Father with the Son,",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 99
# }]
# [{
#   "text": "Sabellians",
#   "type": "PERSON",
#   "start_char": 76,
#   "end_char": 86
# }, {
#   "text": "Rome,",
#   "type": "GPE",
#   "start_char": 140,
#   "end_char": 145
# }, {
#   "text": "Africa,",
#   "type": "NORP",
#   "start_char": 149,
#   "end_char": 156
# }, {
#   "text": "Egypt,",
#   "type": "NORP",
#   "start_char": 163,
#   "end_char": 169
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 506,
#   "end_char": 517
# }, {
#   "text": "Alexandria;",
#   "type": "GPE",
#   "start_char": 625,
#   "end_char": 636
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 764,
#   "end_char": 768
# }]
# [{
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 121,
#   "end_char": 126
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 149,
#   "end_char": 154
# }]
# []
# [{
#   "text": "Alexander",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 29
# }]
# []
# []
# [{
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 22
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 42,
#   "end_char": 45
# }, {
#   "text": "Egypt,",
#   "type": "ORG",
#   "start_char": 57,
#   "end_char": 63
# }, {
#   "text": "seven",
#   "type": "CARDINAL",
#   "start_char": 64,
#   "end_char": 69
# }, {
#   "text": "twelve",
#   "type": "CARDINAL",
#   "start_char": 82,
#   "end_char": 88
# }, {
#   "text": "seven hundred",
#   "type": "CARDINAL",
#   "start_char": 138,
#   "end_char": 151
# }]
# [{
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 35,
#   "end_char": 39
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 118,
#   "end_char": 126
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 164,
#   "end_char": 173
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 191,
#   "end_char": 199
# }, {
#   "text": "Nicomedia,",
#   "type": "ORG",
#   "start_char": 203,
#   "end_char": 213
# }]
# [{
#   "text": "Palestine",
#   "type": "GPE",
#   "start_char": 10,
#   "end_char": 19
# }, {
#   "text": "Bithynia",
#   "type": "GPE",
#   "start_char": 24,
#   "end_char": 32
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 184,
#   "end_char": 187
# }, {
#   "text": "the general council of Nice.",
#   "type": "ORG",
#   "start_char": 240,
#   "end_char": 268
# }, {
#   "text": "Three",
#   "type": "CARDINAL",
#   "start_char": 269,
#   "end_char": 274
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 26,
#   "end_char": 35
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 158,
#   "end_char": 163
# }]
# [{
#   "text": "Arianism",
#   "type": "PERSON",
#   "start_char": 5,
#   "end_char": 13
# }]
# []
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 17,
#   "end_char": 22
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 59,
#   "end_char": 64
# }]
# []
# [{
#   "text": "Son the Almighty Father",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 45
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 202,
#   "end_char": 207
# }, {
#   "text": "Caesar",
#   "type": "PERSON",
#   "start_char": 255,
#   "end_char": 261
# }, {
#   "text": "the will of his Father",
#   "type": "PERSON",
#   "start_char": 321,
#   "end_char": 343
# }]
# []
# [{
#   "text": "second",
#   "type": "ORDINAL",
#   "start_char": 7,
#   "end_char": 13
# }, {
#   "text": "Three",
#   "type": "CARDINAL",
#   "start_char": 153,
#   "end_char": 158
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 202,
#   "end_char": 207
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 57,
#   "end_char": 62
# }]
# []
# []
# []
# [{
#   "text": "Three",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 5
# }]
# []
# []
# [{
#   "text": "Jesus",
#   "type": "PERSON",
#   "start_char": 146,
#   "end_char": 151
# }]
# [{
#   "text": "Sabellian",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 95
# }, {
#   "text": "Ebionite",
#   "type": "NORP",
#   "start_char": 111,
#   "end_char": 119
# }, {
#   "text": "Council of Nice, A.D",
#   "type": "ORG",
#   "start_char": 220,
#   "end_char": 240
# }]
# [{
#   "text": "325",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }]
# [{
#   "text": "the council of Nice(55)",
#   "type": "ORG",
#   "start_char": 18,
#   "end_char": 41
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 115,
#   "end_char": 120
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 283,
#   "end_char": 286
# }]
# [{
#   "text": "Arians",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 10
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 33,
#   "end_char": 42
# }]
# [{
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 183,
#   "end_char": 189
# }]
# [{
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 74,
#   "end_char": 82
# }]
# [{
#   "text": "Ambrose,",
#   "type": "PERSON",
#   "start_char": 150,
#   "end_char": 158
# }]
# [{
#   "text": "The consubstantiality of the Father and the Son",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 47
# }, {
#   "text": "the council of Nice,",
#   "type": "ORG",
#   "start_char": 67,
#   "end_char": 87
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 154,
#   "end_char": 163
# }, {
#   "text": "the Greek, the Latin, the Oriental,",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 223
# }, {
#   "text": "Protestant",
#   "type": "NORP",
#   "start_char": 232,
#   "end_char": 242
# }]
# []
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 31,
#   "end_char": 34
# }, {
#   "text": "Tritheists",
#   "type": "NORP",
#   "start_char": 106,
#   "end_char": 116
# }, {
#   "text": "Sabellians",
#   "type": "PERSON",
#   "start_char": 128,
#   "end_char": 138
# }]
# []
# []
# [{
#   "text": "Sabellian",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 13
# }, {
#   "text": "about fifty years",
#   "type": "DATE",
#   "start_char": 28,
#   "end_char": 45
# }, {
#   "text": "Antioch(57)",
#   "type": "PERSON",
#   "start_char": 81,
#   "end_char": 92
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 39,
#   "end_char": 44
# }, {
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 65,
#   "end_char": 76
# }, {
#   "text": "Gregory Nazianzen,",
#   "type": "PERSON",
#   "start_char": 89,
#   "end_char": 107
# }, {
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 194
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 368,
#   "end_char": 373
# }, {
#   "text": "Father,",
#   "type": "PERSON",
#   "start_char": 687,
#   "end_char": 694
# }]
# []
# []
# []
# [{
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 22
# }, {
#   "text": "Arians,(61)",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 106
# }, {
#   "text": "twenty years",
#   "type": "DATE",
#   "start_char": 129,
#   "end_char": 141
# }, {
#   "text": "the Sabellianism of Marcellus of Ancyra;",
#   "type": "PERSON",
#   "start_char": 142,
#   "end_char": 182
# }, {
#   "text": "Arian Creeds",
#   "type": "PERSON",
#   "start_char": 354,
#   "end_char": 366
# }]
# [{
#   "text": "Arians",
#   "type": "PERSON",
#   "start_char": 49,
#   "end_char": 55
# }]
# []
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 36,
#   "end_char": 41
# }, {
#   "text": "eighteen",
#   "type": "CARDINAL",
#   "start_char": 355,
#   "end_char": 363
# }]
# [{
#   "text": "Hilary,",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 19
# }, {
#   "text": "Oriental",
#   "type": "NORP",
#   "start_char": 145,
#   "end_char": 153
# }, {
#   "text": "ten",
#   "type": "CARDINAL",
#   "start_char": 203,
#   "end_char": 206
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 220,
#   "end_char": 224
# }, {
#   "text": "Poitiers",
#   "type": "GPE",
#   "start_char": 593,
#   "end_char": 601
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 640,
#   "end_char": 649
# }]
# [{
#   "text": "Arian Sects",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# [{
#   "text": "eighteen",
#   "type": "CARDINAL",
#   "start_char": 28,
#   "end_char": 36
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 129,
#   "end_char": 134
# }]
# []
# [{
#   "text": "One",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 45,
#   "end_char": 50
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 135,
#   "end_char": 140
# }, {
#   "text": "the Homoousion of the Nicene",
#   "type": "PERSON",
#   "start_char": 196,
#   "end_char": 224
# }]
# [{
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 167,
#   "end_char": 173
# }]
# [{
#   "text": "Atheist",
#   "type": "NORP",
#   "start_char": 119,
#   "end_char": 126
# }]
# []
# [{
#   "text": "Aristotle,",
#   "type": "GPE",
#   "start_char": 319,
#   "end_char": 329
# }, {
#   "text": "Aetius",
#   "type": "ORG",
#   "start_char": 341,
#   "end_char": 347
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 43,
#   "end_char": 48
# }]
# []
# [{
#   "text": "the Father and the Son;",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 118
# }]
# [{
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 11,
#   "end_char": 17
# }, {
#   "text": "Eusebian",
#   "type": "GPE",
#   "start_char": 133,
#   "end_char": 141
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 198,
#   "end_char": 202
# }]
# [{
#   "text": "Aetius;",
#   "type": "NORP",
#   "start_char": 61,
#   "end_char": 68
# }, {
#   "text": "the Scriptures, that the Son",
#   "type": "WORK_OF_ART",
#   "start_char": 135,
#   "end_char": 163
# }]
# []
# []
# [{
#   "text": "Asia;",
#   "type": "GPE",
#   "start_char": 112,
#   "end_char": 117
# }, {
#   "text": "Seleucia,",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 197
# }, {
#   "text": "one hundred and five to forty-three",
#   "type": "CARDINAL",
#   "start_char": 255,
#   "end_char": 290
# }]
# [{
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 9
# }, {
#   "text": "Homoousians",
#   "type": "NORP",
#   "start_char": 249,
#   "end_char": 260
# }, {
#   "text": "Homoiousians",
#   "type": "NORP",
#   "start_char": 269,
#   "end_char": 281
# }]
# [{
#   "text": "Catholics",
#   "type": "NORP",
#   "start_char": 340,
#   "end_char": 349
# }]
# [{
#   "text": "The bishop of Poitiers,",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 23
# }, {
#   "text": "Phrygian",
#   "type": "NORP",
#   "start_char": 35,
#   "end_char": 43
# }]
# [{
#   "text": "Semi-Arians,",
#   "type": "NORP",
#   "start_char": 129,
#   "end_char": 141
# }, {
#   "text": "Western",
#   "type": "NORP",
#   "start_char": 242,
#   "end_char": 249
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 253,
#   "end_char": 258
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 283,
#   "end_char": 288
# }, {
#   "text": "Asia,",
#   "type": "GPE",
#   "start_char": 293,
#   "end_char": 298
# }, {
#   "text": "Greeks,",
#   "type": "NORP",
#   "start_char": 348,
#   "end_char": 355
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 392,
#   "end_char": 397
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 149,
#   "end_char": 153
# }]
# [{
#   "text": "West",
#   "type": "LOC",
#   "start_char": 23,
#   "end_char": 27
# }, {
#   "text": "Gallican",
#   "type": "NORP",
#   "start_char": 236,
#   "end_char": 244
# }, {
#   "text": "Hilary",
#   "type": "PERSON",
#   "start_char": 258,
#   "end_char": 264
# }, {
#   "text": "thirty years",
#   "type": "DATE",
#   "start_char": 280,
#   "end_char": 292
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 303,
#   "end_char": 308
# }, {
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 354,
#   "end_char": 360
# }, {
#   "text": "Latins",
#   "type": "NORP",
#   "start_char": 376,
#   "end_char": 382
# }]
# [{
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 113,
#   "end_char": 118
# }, {
#   "text": "Gospel",
#   "type": "WORK_OF_ART",
#   "start_char": 218,
#   "end_char": 224
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 275,
#   "end_char": 284
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 337,
#   "end_char": 342
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 593,
#   "end_char": 598
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 736,
#   "end_char": 741
# }]
# [{
#   "text": "Council of Rimi, A.D",
#   "type": "ORG",
#   "start_char": 0,
#   "end_char": 20
# }]
# [{
#   "text": "Rimini,",
#   "type": "PERSON",
#   "start_char": 79,
#   "end_char": 86
# }, {
#   "text": "the council of Nice,",
#   "type": "ORG",
#   "start_char": 114,
#   "end_char": 134
# }, {
#   "text": "four hundred",
#   "type": "CARDINAL",
#   "start_char": 166,
#   "end_char": 178
# }, {
#   "text": "Italy, Africa,",
#   "type": "ORG",
#   "start_char": 190,
#   "end_char": 204
# }, {
#   "text": "Spain, Gaul, Britain,",
#   "type": "PERSON",
#   "start_char": 205,
#   "end_char": 226
# }, {
#   "text": "Illyricum",
#   "type": "GPE",
#   "start_char": 231,
#   "end_char": 240
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 9,
#   "end_char": 14
# }, {
#   "text": "four",
#   "type": "CARDINAL",
#   "start_char": 45,
#   "end_char": 49
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 147,
#   "end_char": 152
# }]
# [{
#   "text": "Valens",
#   "type": "PERSON",
#   "start_char": 133,
#   "end_char": 139
# }, {
#   "text": "Ursacius,",
#   "type": "PERSON",
#   "start_char": 144,
#   "end_char": 153
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 154,
#   "end_char": 157
# }, {
#   "text": "Illyricum,",
#   "type": "GPE",
#   "start_char": 169,
#   "end_char": 179
# }, {
#   "text": "Eusebian",
#   "type": "NORP",
#   "start_char": 282,
#   "end_char": 290
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 455,
#   "end_char": 460
# }]
# [{
#   "text": "Rimini",
#   "type": "GPE",
#   "start_char": 15,
#   "end_char": 21
# }, {
#   "text": "Homoousion",
#   "type": "PERSON",
#   "start_char": 207,
#   "end_char": 217
# }]
# [{
#   "text": "Jerom,",
#   "type": "PERSON",
#   "start_char": 43,
#   "end_char": 49
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 123,
#   "end_char": 128
# }]
# [{
#   "text": "Homoousian",
#   "type": "NORP",
#   "start_char": 79,
#   "end_char": 89
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 236,
#   "end_char": 241
# }, {
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 383,
#   "end_char": 395
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 416,
#   "end_char": 427
# }]
# [{
#   "text": "the King of Heaven",
#   "type": "PERSON",
#   "start_char": 230,
#   "end_char": 248
# }]
# [{
#   "text": "324",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 70,
#   "end_char": 74
# }]
# [{
#   "text": "Alexander",
#   "type": "PERSON",
#   "start_char": 126,
#   "end_char": 135
# }, {
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 143,
#   "end_char": 149
# }]
# []
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 20,
#   "end_char": 29
# }, {
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 201,
#   "end_char": 211
# }, {
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 231,
#   "end_char": 236
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 190,
#   "end_char": 201
# }]
# []
# []
# [{
#   "text": "three hundred",
#   "type": "CARDINAL",
#   "start_char": 251,
#   "end_char": 264
# }]
# []
# [{
#   "text": "Constantine,(78)",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 102
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 105,
#   "end_char": 110
# }, {
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 292,
#   "end_char": 297
# }]
# [{
#   "text": "Osius,",
#   "type": "PERSON",
#   "start_char": 32,
#   "end_char": 38
# }, {
#   "text": "Nice,",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 91
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 195,
#   "end_char": 203
# }]
# [{
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 10
# }, {
#   "text": "Constantine;",
#   "type": "PERSON",
#   "start_char": 33,
#   "end_char": 45
# }]
# [{
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }, {
#   "text": "Casarea",
#   "type": "GPE",
#   "start_char": 12,
#   "end_char": 19
# }, {
#   "text": "the Nicomedian Eusebius",
#   "type": "WORK_OF_ART",
#   "start_char": 114,
#   "end_char": 137
# }, {
#   "text": "about three months",
#   "type": "DATE",
#   "start_char": 159,
#   "end_char": 177
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 223,
#   "end_char": 228
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 241,
#   "end_char": 246
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 265,
#   "end_char": 268
# }, {
#   "text": "Illyricum;",
#   "type": "GPE",
#   "start_char": 296,
#   "end_char": 306
# }, {
#   "text": "Porphyrians;",
#   "type": "PERSON",
#   "start_char": 378,
#   "end_char": 390
# }]
# [{
#   "text": "Christ.(82)",
#   "type": "PERSON",
#   "start_char": 198,
#   "end_char": 209
# }]
# [{
#   "text": "three years",
#   "type": "DATE",
#   "start_char": 95,
#   "end_char": 106
# }]
# [{
#   "text": "Eusebius,",
#   "type": "PERSON",
#   "start_char": 30,
#   "end_char": 39
# }]
# [{
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }]
# [{
#   "text": "Jerusalem;",
#   "type": "GPE",
#   "start_char": 39,
#   "end_char": 49
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 212,
#   "end_char": 226
# }]
# [{
#   "text": "the same day",
#   "type": "DATE",
#   "start_char": 3,
#   "end_char": 15
# }, {
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 56,
#   "end_char": 62
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 9,
#   "end_char": 14
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 51,
#   "end_char": 61
# }, {
#   "text": "Alexandria, Eustathius",
#   "type": "PERSON",
#   "start_char": 65,
#   "end_char": 87
# }, {
#   "text": "Antioch,",
#   "type": "GPE",
#   "start_char": 91,
#   "end_char": 99
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 104,
#   "end_char": 108
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 262,
#   "end_char": 267
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 275,
#   "end_char": 284
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 371,
#   "end_char": 376
# }, {
#   "text": "Nicomedia",
#   "type": "GPE",
#   "start_char": 387,
#   "end_char": 396
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 33,
#   "end_char": 44
# }]
# [{
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 224,
#   "end_char": 230
# }, {
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 246,
#   "end_char": 257
# }, {
#   "text": "Nice",
#   "type": "GPE",
#   "start_char": 293,
#   "end_char": 297
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 320,
#   "end_char": 329
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 382,
#   "end_char": 393
# }]
# []
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 23
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 319,
#   "end_char": 330
# }, {
#   "text": "Constantius,",
#   "type": "PERSON",
#   "start_char": 394,
#   "end_char": 406
# }, {
#   "text": "East,",
#   "type": "NORP",
#   "start_char": 442,
#   "end_char": 447
# }]
# [{
#   "text": "The Arian",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }]
# [{
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 233,
#   "end_char": 244
# }, {
#   "text": "Eusebian",
#   "type": "NORP",
#   "start_char": 274,
#   "end_char": 282
# }, {
#   "text": "Magnentius",
#   "type": "PERSON",
#   "start_char": 394,
#   "end_char": 404
# }, {
#   "text": "Arianism",
#   "type": "PERSON",
#   "start_char": 496,
#   "end_char": 504
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 10,
#   "end_char": 13
# }, {
#   "text": "Mursa,",
#   "type": "PERSON",
#   "start_char": 51,
#   "end_char": 57
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 78,
#   "end_char": 81
# }, {
#   "text": "war, the son of Constantine",
#   "type": "PERSON",
#   "start_char": 115,
#   "end_char": 142
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 37,
#   "end_char": 42
# }]
# [{
#   "text": "Valens",
#   "type": "PERSON",
#   "start_char": 165,
#   "end_char": 171
# }, {
#   "text": "Gallic",
#   "type": "NORP",
#   "start_char": 193,
#   "end_char": 199
# }]
# [{
#   "text": "Mursa,",
#   "type": "PERSON",
#   "start_char": 90,
#   "end_char": 96
# }]
# [{
#   "text": "Arians,",
#   "type": "NORP",
#   "start_char": 9,
#   "end_char": 16
# }, {
#   "text": "Constantius,",
#   "type": "PERSON",
#   "start_char": 60,
#   "end_char": 72
# }, {
#   "text": "Cyril,",
#   "type": "PERSON",
#   "start_char": 120,
#   "end_char": 126
# }, {
#   "text": "Jerusalem,",
#   "type": "GPE",
#   "start_char": 137,
#   "end_char": 147
# }, {
#   "text": "Pentecost,",
#   "type": "EVENT",
#   "start_char": 272,
#   "end_char": 282
# }, {
#   "text": "about the third hour",
#   "type": "TIME",
#   "start_char": 283,
#   "end_char": 303
# }, {
#   "text": "the Mount of Olives,",
#   "type": "LOC",
#   "start_char": 334,
#   "end_char": 354
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 61,
#   "end_char": 66
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 131,
#   "end_char": 134
# }, {
#   "text": "Arian Councils",
#   "type": "ORG",
#   "start_char": 297,
#   "end_char": 311
# }, {
#   "text": "Ammianus,",
#   "type": "PERSON",
#   "start_char": 490,
#   "end_char": 499
# }]
# [{
#   "text": "Constantius",
#   "type": "GPE",
#   "start_char": 79,
#   "end_char": 90
# }]
# [{
#   "text": "Arles, Milan, Sirmium,",
#   "type": "FAC",
#   "start_char": 125,
#   "end_char": 147
# }, {
#   "text": "Constantinople,",
#   "type": "GPE",
#   "start_char": 152,
#   "end_char": 167
# }, {
#   "text": "Nice,",
#   "type": "PERSON",
#   "start_char": 361,
#   "end_char": 366
# }, {
#   "text": "The eunuchs, the women,",
#   "type": "PERSON",
#   "start_char": 460,
#   "end_char": 483
# }, {
#   "text": "Homoousion;",
#   "type": "NORP",
#   "start_char": 607,
#   "end_char": 618
# }, {
#   "text": "Aetius",
#   "type": "PERSON",
#   "start_char": 674,
#   "end_char": 680
# }]
# [{
#   "text": "Gallus;",
#   "type": "PERSON",
#   "start_char": 85,
#   "end_char": 92
# }, {
#   "text": "Imperial",
#   "type": "ORG",
#   "start_char": 120,
#   "end_char": 128
# }, {
#   "text": "Antioch",
#   "type": "GPE",
#   "start_char": 165,
#   "end_char": 172
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 303,
#   "end_char": 308
# }, {
#   "text": "Semi-Arian",
#   "type": "NORP",
#   "start_char": 313,
#   "end_char": 323
# }]
# []
# []
# [{
#   "text": "Gaul, Italy, Illyricum,",
#   "type": "ORG",
#   "start_char": 105,
#   "end_char": 128
# }, {
#   "text": "Asia,",
#   "type": "GPE",
#   "start_char": 133,
#   "end_char": 138
# }, {
#   "text": "Arians,",
#   "type": "NORP",
#   "start_char": 205,
#   "end_char": 212
# }]
# [{
#   "text": "Nicomedia,",
#   "type": "GPE",
#   "start_char": 30,
#   "end_char": 40
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "text": "Isauria;",
#   "type": "GPE",
#   "start_char": 62,
#   "end_char": 70
# }, {
#   "text": "West",
#   "type": "LOC",
#   "start_char": 90,
#   "end_char": 94
# }, {
#   "text": "Rimini,",
#   "type": "GPE",
#   "start_char": 123,
#   "end_char": 130
# }, {
#   "text": "Hadriatic,",
#   "type": "LOC",
#   "start_char": 151,
#   "end_char": 161
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 177,
#   "end_char": 180
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 184,
#   "end_char": 189
# }]
# [{
#   "text": "four days",
#   "type": "DATE",
#   "start_char": 37,
#   "end_char": 46
# }]
# [{
#   "text": "West",
#   "type": "LOC",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "text": "seventh",
#   "type": "ORDINAL",
#   "start_char": 48,
#   "end_char": 55
# }, {
#   "text": "Praetorian",
#   "type": "NORP",
#   "start_char": 75,
#   "end_char": 85
# }, {
#   "text": "fifteen",
#   "type": "CARDINAL",
#   "start_char": 246,
#   "end_char": 253
# }]
# [{
#   "text": "Valens",
#   "type": "PERSON",
#   "start_char": 74,
#   "end_char": 80
# }, {
#   "text": "Ursacius,",
#   "type": "PERSON",
#   "start_char": 85,
#   "end_char": 94
# }, {
#   "text": "Rimini",
#   "type": "GPE",
#   "start_char": 235,
#   "end_char": 241
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 20,
#   "end_char": 24
# }, {
#   "text": "West",
#   "type": "LOC",
#   "start_char": 36,
#   "end_char": 40
# }, {
#   "text": "Constantinople,",
#   "type": "GPE",
#   "start_char": 79,
#   "end_char": 94
# }, {
#   "text": "the Son of God.(95)",
#   "type": "PERSON",
#   "start_char": 251,
#   "end_char": 270
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 432,
#   "end_char": 443
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 553,
#   "end_char": 563
# }]
# [{
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 21,
#   "end_char": 31
# }, {
#   "text": "Trinity,",
#   "type": "NORP",
#   "start_char": 95,
#   "end_char": 103
# }]
# [{
#   "text": "Alexander,",
#   "type": "PERSON",
#   "start_char": 26,
#   "end_char": 36
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 89,
#   "end_char": 94
# }, {
#   "text": "Nicene",
#   "type": "NORP",
#   "start_char": 200,
#   "end_char": 206
# }]
# [{
#   "text": "five months",
#   "type": "DATE",
#   "start_char": 99,
#   "end_char": 110
# }, {
#   "text": "Nice the deacon Athanasius",
#   "type": "PERSON",
#   "start_char": 133,
#   "end_char": 159
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 203,
#   "end_char": 208
# }]
# [{
#   "text": "Arianism",
#   "type": "NORP",
#   "start_char": 136,
#   "end_char": 144
# }]
# [{
#   "text": "Five",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 25
# }, {
#   "text": "twenty years",
#   "type": "DATE",
#   "start_char": 52,
#   "end_char": 64
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 135,
#   "end_char": 140
# }]
# [{
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 52,
#   "end_char": 62
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 189,
#   "end_char": 199
# }, {
#   "text": "Constantine,",
#   "type": "NORP",
#   "start_char": 322,
#   "end_char": 334
# }]
# [{
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 63,
#   "end_char": 71
# }, {
#   "text": "Gregory",
#   "type": "PERSON",
#   "start_char": 159,
#   "end_char": 166
# }, {
#   "text": "Basil;",
#   "type": "PERSON",
#   "start_char": 170,
#   "end_char": 176
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 205,
#   "end_char": 210
# }]
# [{
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 53,
#   "end_char": 56
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 102
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 144,
#   "end_char": 147
# }]
# [{
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 124,
#   "end_char": 135
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 245,
#   "end_char": 255
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 404,
#   "end_char": 409
# }]
# []
# [{
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 18,
#   "end_char": 28
# }]
# [{
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 26
# }]
# [{
#   "text": "Alexandrians",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 16
# }]
# [{
#   "text": "hundred",
#   "type": "CARDINAL",
#   "start_char": 130,
#   "end_char": 137
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 149,
#   "end_char": 154
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 200,
#   "end_char": 210
# }]
# [{
#   "text": "Nile",
#   "type": "LOC",
#   "start_char": 149,
#   "end_char": 153
# }, {
#   "text": "Ethiopia;",
#   "type": "GPE",
#   "start_char": 173,
#   "end_char": 182
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 416,
#   "end_char": 426
# }]
# []
# [{
#   "text": "330",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 32,
#   "end_char": 37
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 113,
#   "end_char": 118
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 271,
#   "end_char": 281
# }]
# [{
#   "text": "the Nicene council",
#   "type": "ORG",
#   "start_char": 174,
#   "end_char": 192
# }, {
#   "text": "Meletius.(102) Athanasius",
#   "type": "PERSON",
#   "start_char": 226,
#   "end_char": 251
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 477,
#   "end_char": 480
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 547,
#   "end_char": 550
# }, {
#   "text": "Arsenius,",
#   "type": "PERSON",
#   "start_char": 578,
#   "end_char": 587
# }, {
#   "text": "seventh",
#   "type": "ORDINAL",
#   "start_char": 590,
#   "end_char": 597
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 777,
#   "end_char": 788
# }, {
#   "text": "Dalmatius,",
#   "type": "PERSON",
#   "start_char": 804,
#   "end_char": 814
# }, {
#   "text": "Caesarea",
#   "type": "GPE",
#   "start_char": 865,
#   "end_char": 873
# }, {
#   "text": "Tyre",
#   "type": "GPE",
#   "start_char": 878,
#   "end_char": 882
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 934,
#   "end_char": 938
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 977,
#   "end_char": 987
# }, {
#   "text": "Jerusalem",
#   "type": "GPE",
#   "start_char": 1062,
#   "end_char": 1071
# }]
# []
# [{
#   "text": "fifty",
#   "type": "CARDINAL",
#   "start_char": 325,
#   "end_char": 330
# }, {
#   "text": "Egyptian",
#   "type": "NORP",
#   "start_char": 331,
#   "end_char": 339
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 362,
#   "end_char": 373
# }, {
#   "text": "Meletians;",
#   "type": "PERSON",
#   "start_char": 416,
#   "end_char": 426
# }, {
#   "text": "Arsenius",
#   "type": "PERSON",
#   "start_char": 431,
#   "end_char": 439
# }]
# [{
#   "text": "Tyre",
#   "type": "GPE",
#   "start_char": 13,
#   "end_char": 17
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 35,
#   "end_char": 43
# }, {
#   "text": "Caesarea,",
#   "type": "GPE",
#   "start_char": 47,
#   "end_char": 56
# }, {
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 269,
#   "end_char": 280
# }, {
#   "text": "Arsenius",
#   "type": "NORP",
#   "start_char": 325,
#   "end_char": 333
# }]
# []
# [{
#   "text": "Arians,",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 11
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 214,
#   "end_char": 217
# }, {
#   "text": "Egyptian",
#   "type": "NORP",
#   "start_char": 315,
#   "end_char": 323
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 419,
#   "end_char": 430
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 537,
#   "end_char": 542
# }]
# [{
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 110,
#   "end_char": 118
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 263,
#   "end_char": 268
# }]
# [{
#   "text": "336",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 126,
#   "end_char": 136
# }]
# [{
#   "text": "Tyre,",
#   "type": "PERSON",
#   "start_char": 166,
#   "end_char": 171
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 344,
#   "end_char": 354
# }, {
#   "text": "Constantine's",
#   "type": "PERSON",
#   "start_char": 400,
#   "end_char": 413
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 546,
# ...
#   "end_char": 23
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 97
# }, {
#   "text": "Rome,",
#   "type": "GPE",
#   "start_char": 106,
#   "end_char": 111
# }, {
#   "text": "Liberius,",
#   "type": "PERSON",
#   "start_char": 421,
#   "end_char": 430
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 288,
#   "end_char": 291
# }, {
#   "text": "Liberius",
#   "type": "NORP",
#   "start_char": 301,
#   "end_char": 309
# }, {
#   "text": "Felix,",
#   "type": "ORG",
#   "start_char": 314,
#   "end_char": 320
# }]
# [{
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 132,
#   "end_char": 143
# }, {
#   "text": "the Circus of Rome,",
#   "type": "WORK_OF_ART",
#   "start_char": 165,
#   "end_char": 184
# }]
# [{
#   "text": "Circus",
#   "type": "FAC",
#   "start_char": 141,
#   "end_char": 147
# }, {
#   "text": "One",
#   "type": "CARDINAL",
#   "start_char": 222,
#   "end_char": 225
# }, {
#   "text": "One",
#   "type": "CARDINAL",
#   "start_char": 234,
#   "end_char": 237
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 263,
#   "end_char": 268
# }, {
#   "text": "Liberius",
#   "type": "PERSON",
#   "start_char": 292,
#   "end_char": 300
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 419,
#   "end_char": 430
# }]
# [{
#   "text": "Felix",
#   "type": "PERSON",
#   "start_char": 161,
#   "end_char": 166
# }, {
#   "text": "Rome,",
#   "type": "PERSON",
#   "start_char": 285,
#   "end_char": 290
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 312,
#   "end_char": 321
# }, {
#   "text": "Marius",
#   "type": "PERSON",
#   "start_char": 375,
#   "end_char": 381
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 419,
#   "end_char": 433
# }]
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 38,
#   "end_char": 48
# }, {
#   "text": "Flavian",
#   "type": "NORP",
#   "start_char": 72,
#   "end_char": 79
# }, {
#   "text": "Rome, Alexandria,",
#   "type": "PERSON",
#   "start_char": 88,
#   "end_char": 105
# }, {
#   "text": "Infidels,",
#   "type": "NORP",
#   "start_char": 197,
#   "end_char": 206
# }]
# [{
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 0,
#   "end_char": 14
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 193,
#   "end_char": 203
# }]
# [{
#   "text": "Alexander the episcopal",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 42
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 66,
#   "end_char": 70
# }, {
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 85
# }]
# [{
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 120,
#   "end_char": 130
# }]
# [{
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 27,
#   "end_char": 33
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 57,
#   "end_char": 61
# }, {
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 149,
#   "end_char": 155
# }]
# [{
#   "text": "the space of fourteen years",
#   "type": "DATE",
#   "start_char": 3,
#   "end_char": 30
# }, {
#   "text": "five",
#   "type": "CARDINAL",
#   "start_char": 38,
#   "end_char": 42
# }, {
#   "text": "Macedonius",
#   "type": "GPE",
#   "start_char": 199,
#   "end_char": 209
# }]
# [{
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 20
# }, {
#   "text": "Mesopotamia",
#   "type": "LOC",
#   "start_char": 69,
#   "end_char": 80
# }, {
#   "text": "Mount",
#   "type": "LOC",
#   "start_char": 112,
#   "end_char": 117
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 175,
#   "end_char": 178
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 247,
#   "end_char": 250
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 315,
#   "end_char": 320
# }]
# [{
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 61,
#   "end_char": 65
# }, {
#   "text": "Hermogenes, the master-general of the cavalry,",
#   "type": "PERSON",
#   "start_char": 88,
#   "end_char": 134
# }]
# [{
#   "text": "Hermogenes",
#   "type": "PERSON",
#   "start_char": 65,
#   "end_char": 75
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 94,
#   "end_char": 99
# }]
# [{
#   "text": "Hermogenes",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 28
# }, {
#   "text": "Philip,",
#   "type": "PERSON",
#   "start_char": 40,
#   "end_char": 47
# }, {
#   "text": "Praetorian",
#   "type": "PERSON",
#   "start_char": 52,
#   "end_char": 62
# }]
# [{
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 70,
#   "end_char": 74
# }, {
#   "text": "Zeuxippus,",
#   "type": "GPE",
#   "start_char": 91,
#   "end_char": 101
# }]
# [{
#   "text": "Thessalonica",
#   "type": "GPE",
#   "start_char": 195,
#   "end_char": 207
# }]
# [{
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 102,
#   "end_char": 112
# }]
# [{
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 64,
#   "end_char": 70
# }, {
#   "text": "three thousand one",
#   "type": "CARDINAL",
#   "start_char": 139,
#   "end_char": 157
# }, {
#   "text": "hundred and fifty",
#   "type": "CARDINAL",
#   "start_char": 158,
#   "end_char": 175
# }]
# [{
#   "text": "Macedonius,",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 45,
#   "end_char": 56
# }, {
#   "text": "St",
#   "type": "GPE",
#   "start_char": 170,
#   "end_char": 172
# }]
# [{
#   "text": "Acacius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }]
# [{
#   "text": "Homoousian",
#   "type": "NORP",
#   "start_char": 116,
#   "end_char": 126
# }]
# [{
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 101,
#   "end_char": 104
# }]
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 361,
#   "end_char": 371
# }, {
#   "text": "Cruelty of the Arians",
#   "type": "PERSON",
#   "start_char": 396,
#   "end_char": 417
# }, {
#   "text": "Constantius,",
#   "type": "GPE",
#   "start_char": 457,
#   "end_char": 469
# }, {
#   "text": "Greeks",
#   "type": "NORP",
#   "start_char": 797,
#   "end_char": 803
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 836,
#   "end_char": 839
# }, {
#   "text": "Hermogenes,",
#   "type": "PERSON",
#   "start_char": 908,
#   "end_char": 919
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 949,
#   "end_char": 963
# }]
# [{
#   "text": "Constantius",
#   "type": "GPE",
#   "start_char": 15,
#   "end_char": 26
# }, {
#   "text": "Theodosian",
#   "type": "NORP",
#   "start_char": 101,
#   "end_char": 111
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 160,
#   "end_char": 165
# }, {
#   "text": "Christians;",
#   "type": "NORP",
#   "start_char": 279,
#   "end_char": 290
# }]
# [{
#   "text": "Thrace",
#   "type": "LOC",
#   "start_char": 53,
#   "end_char": 59
# }, {
#   "text": "Asia Minor",
#   "type": "LOC",
#   "start_char": 64,
#   "end_char": 74
# }, {
#   "text": "Macedonius;",
#   "type": "GPE",
#   "start_char": 104,
#   "end_char": 115
# }, {
#   "text": "Semi-Arian",
#   "type": "NORP",
#   "start_char": 218,
#   "end_char": 228
# }, {
#   "text": "Homoiousion",
#   "type": "PERSON",
#   "start_char": 258,
#   "end_char": 269
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 321,
#   "end_char": 332
# }]
# [{
#   "text": "Macedonius",
#   "type": "GPE",
#   "start_char": 128,
#   "end_char": 138
# }]
# [{
#   "text": "Novatians",
#   "type": "NORP",
#   "start_char": 399,
#   "end_char": 408
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 412,
#   "end_char": 426
# }, {
#   "text": "Homoousian",
#   "type": "NORP",
#   "start_char": 485,
#   "end_char": 495
# }]
# [{
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }, {
#   "text": "Paphlagonia",
#   "type": "GPE",
#   "start_char": 49,
#   "end_char": 60
# }]
# [{
#   "text": "four thousand",
#   "type": "CARDINAL",
#   "start_char": 157,
#   "end_char": 170
# }, {
#   "text": "Mantinium",
#   "type": "GPE",
#   "start_char": 243,
#   "end_char": 252
# }]
# [{
#   "text": "Novatian",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 12
# }, {
#   "text": "Paphlagonians",
#   "type": "NORP",
#   "start_char": 137,
#   "end_char": 150
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 167,
#   "end_char": 172
# }, {
#   "text": "four",
#   "type": "CARDINAL",
#   "start_char": 314,
#   "end_char": 318
# }, {
#   "text": "thousand",
#   "type": "CARDINAL",
#   "start_char": 319,
#   "end_char": 327
# }]
# [{
#   "text": "Constantius",
#   "type": "ORG",
#   "start_char": 17,
#   "end_char": 28
# }, {
#   "text": "East,",
#   "type": "NORP",
#   "start_char": 163,
#   "end_char": 168
# }]
# []
# [{
#   "text": "345",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 32,
#   "end_char": 37
# }, {
#   "text": "African",
#   "type": "NORP",
#   "start_char": 89,
#   "end_char": 96
# }, {
#   "text": "Circumcellions,",
#   "type": "PERSON",
#   "start_char": 192,
#   "end_char": 207
# }, {
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 247,
#   "end_char": 255
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 42,
#   "end_char": 53
# }, {
#   "text": "Constans",
#   "type": "PERSON",
#   "start_char": 138,
#   "end_char": 146
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 236,
#   "end_char": 241
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 325,
#   "end_char": 328
# }, {
#   "text": "Imperial",
#   "type": "NORP",
#   "start_char": 329,
#   "end_char": 337
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 353,
#   "end_char": 357
# }, {
#   "text": "Macarius,",
#   "type": "PERSON",
#   "start_char": 362,
#   "end_char": 371
# }]
# [{
#   "text": "Numidia",
#   "type": "GPE",
#   "start_char": 49,
#   "end_char": 56
# }, {
#   "text": "Mauritania",
#   "type": "GPE",
#   "start_char": 61,
#   "end_char": 71
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 155,
#   "end_char": 160
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 205,
#   "end_char": 214
# }, {
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 300,
#   "end_char": 308
# }]
# []
# []
# []
# [{
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 39,
#   "end_char": 47
# }, {
#   "text": "the Gaetulian desert,",
#   "type": "LOC",
#   "start_char": 102,
#   "end_char": 123
# }]
# [{
#   "text": "Circumcellions",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 33
# }, {
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 364,
#   "end_char": 370
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 3,
#   "end_char": 8
# }]
# [{
#   "text": "Circumcellions",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 107
# }]
# []
# [{
#   "text": "Circumcellions",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 32
# }, {
#   "text": "Bagai",
#   "type": "GPE",
#   "start_char": 185,
#   "end_char": 190
# }, {
#   "text": "Imperial",
#   "type": "ORG",
#   "start_char": 279,
#   "end_char": 287
# }]
# [{
#   "text": "Donatists",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 13
# }]
# []
# [{
#   "text": "the beginning of the present century",
#   "type": "DATE",
#   "start_char": 3,
#   "end_char": 39
# }, {
#   "text": "Circumcellions",
#   "type": "PERSON",
#   "start_char": 59,
#   "end_char": 73
# }, {
#   "text": "Camisards;",
#   "type": "PERSON",
#   "start_char": 162,
#   "end_char": 172
# }, {
#   "text": "Languedoc",
#   "type": "GPE",
#   "start_char": 196,
#   "end_char": 205
# }, {
#   "text": "Numidia",
#   "type": "GPE",
#   "start_char": 225,
#   "end_char": 232
# }, {
#   "text": "Africans",
#   "type": "NORP",
#   "start_char": 269,
#   "end_char": 277
# }, {
#   "text": "Donatists",
#   "type": "PERSON",
#   "start_char": 465,
#   "end_char": 474
# }]
# []
# []
# []
# []
# [{
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 67,
#   "end_char": 70
# }, {
#   "text": "Satan,",
#   "type": "PERSON",
#   "start_char": 144,
#   "end_char": 150
# }, {
#   "text": "Jewish",
#   "type": "NORP",
#   "start_char": 318,
#   "end_char": 324
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 358,
#   "end_char": 367
# }]
# []
# [{
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 147,
#   "end_char": 152
# }]
# [{
#   "text": "Ammianus",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 26
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 68,
#   "end_char": 78
# }, {
#   "text": "Gregory Nazianzen",
#   "type": "PERSON",
#   "start_char": 157,
#   "end_char": 174
# }]
# []
# []
# []
# []
# []
# [{
#   "text": "Athanasians",
#   "type": "NORP",
#   "start_char": 157,
#   "end_char": 168
# }, {
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 177,
#   "end_char": 183
# }, {
#   "text": "Montesquieu,",
#   "type": "PERSON",
#   "start_char": 546,
#   "end_char": 558
# }, {
#   "text": "Constantine,",
#   "type": "GPE",
#   "start_char": 644,
#   "end_char": 656
# }, {
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 686,
#   "end_char": 691
# }]
# [{
#   "text": "Imperial",
#   "type": "NORP",
#   "start_char": 322,
#   "end_char": 330
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 389,
#   "end_char": 400
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 72,
#   "end_char": 77
# }]
# [{
#   "text": "Paganism",
#   "type": "NORP",
#   "start_char": 32,
#   "end_char": 40
# }]
# [{
#   "text": "Pagans,",
#   "type": "NORP",
#   "start_char": 87,
#   "end_char": 94
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 102,
#   "end_char": 111
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 199,
#   "end_char": 210
# }]
# []
# [{
#   "text": "Nile",
#   "type": "LOC",
#   "start_char": 139,
#   "end_char": 143
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 164,
#   "end_char": 175
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 203,
#   "end_char": 208
# }, {
#   "text": "Phoenicia,",
#   "type": "GPE",
#   "start_char": 278,
#   "end_char": 288
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 422,
#   "end_char": 436
# }, {
#   "text": "Greece",
#   "type": "GPE",
#   "start_char": 541,
#   "end_char": 547
# }, {
#   "text": "Asia;",
#   "type": "GPE",
#   "start_char": 552,
#   "end_char": 557
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 60,
#   "end_char": 65
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 23
# }]
# [{
#   "text": "Christians;",
#   "type": "NORP",
#   "start_char": 132,
#   "end_char": 143
# }, {
#   "text": "Paganism,",
#   "type": "NORP",
#   "start_char": 193,
#   "end_char": 202
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 255,
#   "end_char": 258
# }, {
#   "text": "Constans",
#   "type": "NORP",
#   "start_char": 300,
#   "end_char": 308
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 313,
#   "end_char": 324
# }]
# [{
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 29
# }]
# []
# [{
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 130,
#   "end_char": 135
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 182,
#   "end_char": 193
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 7,
#   "end_char": 11
# }, {
#   "text": "West,",
#   "type": "LOC",
#   "start_char": 30,
#   "end_char": 35
# }]
# [{
#   "text": "About four years",
#   "type": "DATE",
#   "start_char": 0,
#   "end_char": 16
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 62,
#   "end_char": 73
# }, {
#   "text": "Rome;",
#   "type": "GPE",
#   "start_char": 97,
#   "end_char": 102
# }, {
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 156,
#   "end_char": 161
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 103,
#   "end_char": 114
# }]
# [{
#   "text": "Numa,",
#   "type": "PERSON",
#   "start_char": 93,
#   "end_char": 98
# }, {
#   "text": "Augustus,",
#   "type": "PERSON",
#   "start_char": 114,
#   "end_char": 123
# }, {
#   "text": "seven",
#   "type": "CARDINAL",
#   "start_char": 162,
#   "end_char": 167
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 168,
#   "end_char": 177
# }]
# [{
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 23,
#   "end_char": 35
# }, {
#   "text": "(173)",
#   "type": "CARDINAL",
#   "start_char": 68,
#   "end_char": 73
# }]
# [{
#   "text": "Imperial",
#   "type": "NORP",
#   "start_char": 162,
#   "end_char": 170
# }]
# [{
#   "text": "Christianity;",
#   "type": "NORP",
#   "start_char": 92,
#   "end_char": 105
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 110,
#   "end_char": 113
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 117,
#   "end_char": 122
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 69,
#   "end_char": 74
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 85,
#   "end_char": 96
# }, {
#   "text": "Constantius;",
#   "type": "PERSON",
#   "start_char": 101,
#   "end_char": 113
# }]
# []
# [{
#   "text": "Gaul",
#   "type": "PERSON",
#   "start_char": 226,
#   "end_char": 230
# }]

# %%
NER_Dict= {}
for doc in Gibbon_out_docs:
    for sent in doc.sentences:
        for token in sent.tokens:
            if token.ner == 'O':
                continue
            else:
                NER_Dict[token.text]= token.ner
           
NER_Dict
# Out:
# {'The': 'B-PERSON',
#  'Schism': 'B-PERSON',
#  'of': 'I-DATE',
#  'the': 'I-DATE',
#  'Donatists': 'S-PERSON',
#  'Arian': 'S-NORP',
#  'Controversy': 'I-WORK_OF_ART',
#  '—': 'I-WORK_OF_ART',
#  'Athanasius': 'S-PERSON',
#  'Distracted': 'I-WORK_OF_ART',
#  'state': 'I-WORK_OF_ART',
#  'Church': 'I-WORK_OF_ART',
#  'and': 'I-CARDINAL',
#  'Empire': 'I-WORK_OF_ART',
#  'under': 'I-WORK_OF_ART',
#  'Constantine': 'S-PERSON',
#  'Toleration': 'B-WORK_OF_ART',
#  'Paganism': 'S-NORP',
#  'Milan,': 'B-PERSON',
#  'Roman': 'S-NORP',
#  'Catholic': 'S-NORP',
#  'Christianity': 'S-NORP',
#  'East': 'S-LOC',
#  'Paul': 'S-PERSON',
#  'Samosata;': 'I-PERSON',
#  'Montanists': 'I-PERSON',
#  'Phrygia,': 'E-PERSON',
#  'Novatians,': 'S-NORP',
#  'Marcionites': 'S-NORP',
#  'Valentinians,': 'S-NORP',
#  'Gnostics': 'S-NORP',
#  'Asia': 'B-LOC',
#  'Egypt': 'S-GPE',
#  'Manichaeans,': 'S-NORP',
#  'Persia': 'S-GPE',
#  'Oriental': 'S-NORP',
#  'Christian': 'S-NORP',
#  'Diocletian;': 'S-PERSON',
#  'Two': 'B-DATE',
#  'Manichaeans': 'S-NORP',
#  'Constantinople;': 'S-GPE',
#  'Acesius,': 'S-PERSON',
#  'Nice;': 'S-PERSON',
#  'African': 'S-NORP',
#  '312': 'S-CARDINAL',
#  'Constantine,': 'S-GPE',
#  'Maxentius': 'S-PERSON',
#  'Africa': 'S-LOC',
#  'Columns': 'I-ORG',
#  'Hercules,': 'E-ORG',
#  'Carthage,': 'S-GPE',
#  'second': 'S-ORDINAL',
#  'West': 'S-LOC',
#  'Caecilian': 'E-GPE',
#  'Majourinus': 'S-ORG',
#  'two': 'S-CARDINAL',
#  'Cacilian': 'S-PERSON',
#  'Numidia': 'S-GPE',
#  'Caecilian,': 'S-PERSON',
#  'Majorinus,': 'S-PERSON',
#  'Numidian': 'S-NORP',
#  'Holy': 'I-WORK_OF_ART',
#  'Scriptures': 'E-PERSON',
#  'Diocletian': 'S-PERSON',
#  'Christians': 'S-NORP',
#  'five': 'S-CARDINAL',
#  'first': 'S-ORDINAL',
#  'three': 'S-CARDINAL',
#  'years': 'E-DATE',
#  'Africa,': 'E-ORG',
#  'Rome': 'S-GPE',
#  'Arles,': 'S-PERSON',
#  'Caecilian;': 'S-PERSON',
#  'Donatist': 'S-NORP',
#  'Osius': 'S-PERSON',
#  'Donatists,': 'I-PERSON',
#  'A.D': 'E-GPE',
#  '315': 'S-CARDINAL',
#  'Europe': 'S-LOC',
#  'East,': 'S-NORP',
#  'Eucharist': 'E-PERSON',
#  'Numidia,': 'S-GPE',
#  'four': 'I-DATE',
#  'hundred': 'B-CARDINAL',
#  'fourth': 'S-ORDINAL',
#  'Rogatians': 'S-NORP',
#  'Caesarean': 'I-LOC',
#  'Mauritania.(10)': 'E-LOC',
#  'Trinitarian': 'S-NORP',
#  'Clovis': 'S-PERSON',
#  'Theodoric,': 'S-PERSON',
#  'Romans': 'S-NORP',
#  'Arianism': 'S-NORP',
#  'Plato': 'S-PERSON',
#  'Christ': 'B-PERSON',
#  '360': 'E-PERSON',
#  'Plato,': 'S-GPE',
#  'Athenian': 'S-NORP',
#  'Platonic': 'S-NORP',
#  'Logos': 'S-ORG',
#  'Son': 'I-PERSON',
#  'an': 'B-DATE',
#  'Eternal': 'E-PERSON',
#  'Academy;': 'S-NORP',
#  'thirty': 'B-DATE',
#  'years.(12)': 'E-DATE',
#  'Alexandria': 'S-GPE',
#  '300': 'E-PERSON',
#  'Macedonians': 'S-NORP',
#  'Greece;': 'S-LANGUAGE',
#  'Alexandria.': 'S-GPE',
#  'Jews': 'S-NORP',
#  'Hebrews': 'S-NORP',
#  'Egyptian': 'S-NORP',
#  'One': 'S-CARDINAL',
#  'before': 'E-DATE',
#  'Christ,': 'E-PERSON',
#  'Alexandrian': 'S-NORP',
#  'Solomon': 'S-PERSON',
#  'Mosaic': 'S-NORP',
#  'Grecian': 'S-NORP',
#  'Philo,': 'S-PERSON',
#  'Hebrews;': 'S-PERSON',
#  'to': 'I-WORK_OF_ART',
#  'Jehovah': 'I-WORK_OF_ART',
#  'Moses': 'E-WORK_OF_ART',
#  'God': 'E-PERSON',
#  'Apostle': 'I-PERSON',
#  'St': 'S-GPE',
#  'John,': 'I-PERSON',
#  '97': 'S-CARDINAL',
#  'Alexandria,': 'E-PERSON',
#  'Deity,': 'E-PERSON',
#  'Academy,': 'B-PERSON',
#  'Porch,': 'E-PERSON',
#  'Nerva,': 'S-PERSON',
#  'Jesus': 'S-PERSON',
#  'Nazareth;': 'E-PERSON',
#  'Ebionites': 'S-PERSON',
#  'Docetes': 'S-ORG',
#  'Nazarenes,(23)': 'S-PERSON',
#  'Hewbrew': 'S-NORP',
#  'God,': 'E-PERSON',
#  'John': 'S-PERSON',
#  'About': 'B-DATE',
#  'fifty': 'E-CARDINAL',
#  'Ebionites,': 'S-NORP',
#  'Justin': 'B-PERSON',
#  'Martyr,': 'E-PERSON',
#  'Gnostics,': 'S-NORP',
#  'Aeon,': 'S-PERSON',
#  'Emanation': 'B-PERSON',
#  'Mount': 'S-LOC',
#  'Calvary,': 'E-LOC',
#  'Virgin,(27)': 'S-PERSON',
#  'Jordan': 'S-GPE',
#  'Pilate': 'S-PERSON',
#  'days,': 'E-DATE',
#  'Mysterious': 'B-PERSON',
#  'nature': 'I-PERSON',
#  'Trinity': 'E-PERSON',
#  'third': 'I-TIME',
#  'centuries': 'E-DATE',
#  'Trinity,(31)': 'S-PERSON',
#  'divinity': 'I-PERSON',
#  'Logos,': 'E-PERSON',
#  'Zeal': 'B-PERSON',
#  'Christians.': 'E-PERSON',
#  'Athens': 'S-GPE',
#  'Tertullian': 'S-PERSON',
#  'Greek': 'S-NORP',
#  'eternal': 'E-PERSON',
#  'Bithynia': 'S-GPE',
#  'Pliny': 'S-PERSON',
#  'Father': 'I-PERSON',
#  'Platonists:': 'S-NORP',
#  'Praxeas': 'S-GPE',
#  'Sabellius': 'S-PERSON',
#  'with': 'I-PERSON',
#  'Son,': 'E-PERSON',
#  'Sabellians': 'S-PERSON',
#  'Rome,': 'B-PERSON',
#  'Egypt,': 'E-PERSON',
#  'Alexandria;': 'S-GPE',
#  'Arius': 'S-PERSON',
#  'Alexander': 'B-PERSON',
#  'seven': 'S-CARDINAL',
#  'twelve': 'S-CARDINAL',
#  'Eusebius': 'E-PERSON',
#  'Nicomedia,': 'S-GPE',
#  'Palestine': 'S-GPE',
#  'six': 'S-CARDINAL',
#  'general': 'I-ORG',
#  'council': 'I-ORG',
#  'Nice.': 'E-ORG',
#  'Three': 'S-CARDINAL',
#  'Almighty': 'I-PERSON',
#  'Caesar': 'S-PERSON',
#  'will': 'I-PERSON',
#  'his': 'I-PERSON',
#  'Sabellian': 'S-NORP',
#  'Ebionite': 'S-NORP',
#  'Council': 'B-ORG',
#  'Nice,': 'S-PERSON',
#  '325': 'S-CARDINAL',
#  'Nice(55)': 'E-ORG',
#  'Arians': 'S-NORP',
#  'Ambrose,': 'S-PERSON',
#  'consubstantiality': 'I-PERSON',
#  'Greek,': 'I-PERSON',
#  'Latin,': 'I-PERSON',
#  'Oriental,': 'E-PERSON',
#  'Protestant': 'S-NORP',
#  'Tritheists': 'S-NORP',
#  'about': 'B-DATE',
#  'Antioch(57)': 'S-PERSON',
#  'Athanasius,': 'S-GPE',
#  'Gregory': 'B-PERSON',
#  'Nazianzen,': 'E-PERSON',
#  'Nicene': 'S-PERSON',
#  'Father,': 'E-WORK_OF_ART',
#  'Arians,(61)': 'S-PERSON',
#  'twenty': 'I-DATE',
#  'Sabellianism': 'I-PERSON',
#  'Marcellus': 'I-PERSON',
#  'Ancyra;': 'E-PERSON',
#  'Creeds': 'E-PERSON',
#  'eighteen': 'S-CARDINAL',
#  'Hilary,': 'S-PERSON',
#  'ten': 'S-CARDINAL',
#  'Poitiers': 'S-GPE',
#  'Sects': 'E-PERSON',
#  'Homoousion': 'S-PERSON',
#  'Arius,': 'S-PERSON',
#  'Atheist': 'S-NORP',
#  'Aristotle,': 'S-GPE',
#  'Aetius': 'S-PERSON',
#  'Son;': 'E-PERSON',
#  'Eusebian': 'S-NORP',
#  'Aetius;': 'S-NORP',
#  'Scriptures,': 'I-WORK_OF_ART',
#  'that': 'B-TIME',
#  'Asia;': 'S-GPE',
#  'Seleucia,': 'B-GPE',
#  'one': 'S-CARDINAL',
#  'forty-three': 'E-CARDINAL',
#  'Homoousians': 'S-NORP',
#  'Homoiousians': 'S-NORP',
#  'Catholics': 'S-NORP',
#  'bishop': 'I-PERSON',
#  'Poitiers,': 'E-PERSON',
#  'Phrygian': 'S-NORP',
#  'Semi-Arians,': 'S-NORP',
#  'Western': 'S-NORP',
#  'Latin': 'S-NORP',
#  'Asia,': 'S-NORP',
#  'Greeks,': 'S-NORP',
#  'Gallican': 'S-NORP',
#  'Hilary': 'B-PERSON',
#  'Latins': 'S-NORP',
#  'Gospel': 'S-WORK_OF_ART',
#  'Rimi,': 'I-ORG',
#  'Rimini,': 'S-GPE',
#  'Italy,': 'I-ORG',
#  'Spain,': 'B-PERSON',
#  'Gaul,': 'S-GPE',
#  'Britain,': 'E-PERSON',
#  'Illyricum': 'S-GPE',
#  'Valens': 'S-PERSON',
#  'Ursacius,': 'S-PERSON',
#  'Illyricum,': 'E-ORG',
#  'Rimini': 'S-GPE',
#  'Jerom,': 'S-PERSON',
#  'Homoousian': 'S-NORP',
#  'King': 'I-PERSON',
#  'Heaven': 'E-PERSON',
#  '324': 'S-CARDINAL',
#  'Constantine,(78)': 'S-PERSON',
#  'Osius,': 'S-PERSON',
#  'Constantine;': 'S-PERSON',
#  'Casarea': 'S-GPE',
#  'Nicomedian': 'I-WORK_OF_ART',
#  'months': 'E-DATE',
#  'Illyricum;': 'S-GPE',
#  'Porphyrians;': 'S-PERSON',
#  'Christ.(82)': 'S-PERSON',
#  'Eusebius,': 'S-PERSON',
#  'Jerusalem;': 'S-GPE',
#  'Constantinople': 'S-GPE',
#  'same': 'I-DATE',
#  'day': 'E-DATE',
#  'Eustathius': 'S-PERSON',
#  'Antioch,': 'B-WORK_OF_ART',
#  'Nicomedia': 'S-GPE',
#  'Nice': 'B-PERSON',
#  'Constantius': 'S-PERSON',
#  'Constantius,': 'S-GPE',
#  'Magnentius': 'S-PERSON',
#  'Mursa,': 'S-PERSON',
#  'war,': 'B-PERSON',
#  'son': 'I-PERSON',
#  'Gallic': 'S-NORP',
#  'Arians,': 'S-NORP',
#  'Cyril,': 'S-PERSON',
#  'Jerusalem,': 'S-GPE',
#  'Pentecost,': 'S-EVENT',
#  'hour': 'E-TIME',
#  'Olives,': 'E-LOC',
#  'Councils': 'E-ORG',
#  'Ammianus,': 'S-PERSON',
#  'Sirmium,': 'E-FAC',
#  'Constantinople,': 'S-GPE',
#  'eunuchs,': 'I-PERSON',
#  'women,': 'E-PERSON',
#  'Homoousion;': 'S-NORP',
#  'Gallus;': 'S-PERSON',
#  'Imperial': 'S-NORP',
#  'Antioch': 'S-GPE',
#  'Semi-Arian': 'S-NORP',
#  'Isauria;': 'S-GPE',
#  'Hadriatic,': 'S-LOC',
#  'days': 'E-DATE',
#  'seventh': 'S-ORDINAL',
#  'Praetorian': 'S-PERSON',
#  'fifteen': 'S-CARDINAL',
#  'God.(95)': 'E-PERSON',
#  'Trinity,': 'S-NORP',
#  'Alexander,': 'S-PERSON',
#  'deacon': 'I-PERSON',
#  'Five': 'S-CARDINAL',
#  'Basil;': 'S-PERSON',
#  'Alexandrians': 'S-NORP',
#  'Nile': 'S-LOC',
#  'Ethiopia;': 'S-GPE',
#  '330': 'S-CARDINAL',
#  'Meletius.(102)': 'B-PERSON',
#  'Arsenius,': 'S-PERSON',
#  'Dalmatius,': 'S-PERSON',
#  'Caesarea': 'S-GPE',
#  'Tyre': 'S-GPE',
#  'Jerusalem': 'S-GPE',
#  'Meletians;': 'S-PERSON',
#  'Arsenius': 'S-NORP',
#  'Caesarea,': 'S-GPE',
#  '336': 'S-CARDINAL',
#  'Tyre,': 'S-GPE',
#  "Constantine's": 'S-PERSON',
#  'Treves,': 'B-ORG',
#  'twenty-eight': 'I-DATE',
#  '338': 'S-CARDINAL',
#  '341': 'S-CARDINAL',
#  'Eusebians': 'S-PERSON',
#  'Ninety': 'S-CARDINAL',
#  'Semi-Arianism,': 'S-NORP',
#  'twenty-five': 'S-CARDINAL',
#  'Greeks': 'S-NORP',
#  'Athanasius;': 'S-PERSON',
#  'Gregory,': 'S-PERSON',
#  'Asiatic': 'S-NORP',
#  'Julius:': 'S-PERSON',
#  'Italy': 'S-GPE',
#  'Milan': 'S-GPE',
#  'Constans,': 'S-PERSON',
#  'Constans': 'S-NORP',
#  'Ninety-four': 'S-CARDINAL',
#  'West,': 'S-LOC',
#  'Sardica,': 'S-GPE',
#  'dominions': 'I-PERSON',
#  'protector': 'I-PERSON',
#  'Thrace;': 'S-GPE',
#  'East.(115)': 'B-ORG',
#  'Sardica': 'E-ORG',
#  '349': 'S-CARDINAL',
#  'Capua,': 'S-GPE',
#  'Lodi,': 'B-ORG',
#  'Verona,': 'I-ORG',
#  'Padua,': 'I-ORG',
#  'Aquileia,': 'E-ORG',
#  'Treves': 'S-GPE',
#  'Syria;': 'S-NORP',
#  'Constantius;': 'S-PERSON',
#  'Alexandrians;': 'S-PERSON',
#  'Ethiopia': 'S-GPE',
#  '351': 'S-CARDINAL',
#  'years,': 'E-DATE',
#  'Arles': 'S-GPE',
#  'Eastern': 'S-NORP',
#  'Archbishop': 'I-PERSON',
#  'Sardica(126)': 'S-GPE',
#  '355': 'S-CARDINAL',
#  'Athanasius)': 'S-PERSON',
#  'Eastern,': 'S-NORP',
#  'Liberius': 'S-PERSON',
#  'Cordova,': 'S-PERSON',
#  'Paulinus': 'E-PERSON',
#  'Dionysius': 'E-ORG',
#  'Vercellae,': 'B-PERSON',
#  'Lucifer': 'E-PERSON',
#  'Cagliari,': 'S-GPE',
#  'Liberius,': 'S-PERSON',
#  'Cordova': 'S-GPE',
#  'Spaniard': 'S-NORP',
#  'Maximian': 'S-PERSON',
#  'Roman,': 'E-PERSON',
#  'Beraea': 'S-PERSON',
#  'Thrace,': 'S-PERSON',
#  'years;': 'E-DATE',
#  'Cappadocia,': 'S-GPE',
#  'likeness,': 'I-PERSON',
#  'Third': 'S-ORDINAL',
#  '356': 'S-CARDINAL',
#  'Six-and-twenty': 'B-DATE',
#  'court': 'E-ORG',
#  'Upper': 'I-PERSON',
#  'Libya,': 'S-NORP',
#  'twenty-three': 'B-DATE',
#  'Syrianus,': 'B-PERSON',
#  'duke': 'I-PERSON',
#  'thousand': 'S-CARDINAL',
#  'Syrianus': 'S-GPE',
#  'Pagans': 'S-NORP',
#  'George': 'S-PERSON',
#  'Cappadocia': 'S-GPE',
#  'Sebastian,': 'S-PERSON',
#  'more': 'B-CARDINAL',
#  'than': 'I-CARDINAL',
#  'ninety': 'E-CARDINAL',
#  'George,': 'S-PERSON',
#  'memorable': 'I-TIME',
#  'night': 'E-TIME',
#  'Theonas': 'S-PERSON',
#  'David': 'S-PERSON',
#  'Israel': 'S-GPE',
#  'moment': 'E-TIME',
#  '356-362': 'S-CARDINAL',
#  'Ethiopia,': 'S-NORP',
#  'Antony': 'S-PERSON',
#  'Pachomius': 'S-PERSON',
#  'Nile;': 'S-LOC',
#  'Tabenne': 'S-PERSON',
#  'several': 'B-CARDINAL',
#  'only': 'B-DATE',
#  'age,': 'E-DATE',
#  'midnight,': 'E-TIME',
#  '(143)': 'E-GPE',
#  'Mediterranean': 'S-LOC',
#  'Arians;': 'S-PERSON',
#  'Anti-christ': 'I-PERSON',
#  'church': 'E-PERSON',
#  'Gallus,': 'S-PERSON',
#  'Sylvanus,': 'S-PERSON',
#  'Magnentius,': 'S-PERSON',
#  'Bishops': 'E-PERSON',
#  'Christians,': 'S-NORP',
#  'Flavianus': 'B-ORG',
#  'Diodorus,': 'E-ORG',
#  'Glory': 'I-WORK_OF_ART',
#  'Ghost': 'E-WORK_OF_ART',
#  'three,': 'B-CARDINAL',
#  'or': 'I-CARDINAL',
#  'even': 'I-CARDINAL',
#  'Felix,': 'S-ORG',
#  'Circus': 'S-FAC',
#  'Felix': 'S-PERSON',
#  'Marius': 'S-PERSON',
#  'Flavian': 'S-NORP',
#  'Infidels,': 'S-NORP',
#  'episcopal': 'E-PERSON',
#  'Macedonius': 'S-PERSON',
#  'space': 'I-DATE',
#  'fourteen': 'I-DATE',
#  'Mesopotamia': 'S-LOC',
#  'Hermogenes,': 'S-PERSON',
#  'master-general': 'I-PERSON',
#  'cavalry,': 'E-PERSON',
#  'Hermogenes': 'S-PERSON',
#  'Philip,': 'S-PERSON',
#  'Zeuxippus,': 'S-GPE',
#  'Thessalonica': 'S-GPE',
#  'Macedonius,': 'S-PERSON',
#  'Acacius': 'S-PERSON',
#  'Cruelty': 'B-PERSON',
#  'Theodosian': 'S-NORP',
#  'Christians;': 'S-NORP',
#  'Thrace': 'S-LOC',
#  'Minor': 'E-LOC',
#  'Macedonius;': 'S-GPE',
#  'Homoiousion': 'S-PERSON',
#  'Novatians': 'S-NORP',
#  'Paphlagonia': 'S-GPE',
#  'Mantinium': 'S-GPE',
#  'Novatian': 'S-NORP',
#  'Paphlagonians': 'S-NORP',
#  '345': 'S-CARDINAL',
#  'Circumcellions,': 'S-PERSON',
#  'Macarius,': 'S-PERSON',
#  'Mauritania': 'S-GPE',
#  'Gaetulian': 'I-LOC',
#  'desert,': 'E-LOC',
#  'Circumcellions': 'S-PERSON',
#  'Bagai': 'S-GPE',
#  'beginning': 'I-DATE',
#  'present': 'I-DATE',
#  'century': 'E-DATE',
#  'Camisards;': 'S-PERSON',
#  'Languedoc': 'S-GPE',
#  'Africans': 'S-NORP',
#  'Satan,': 'S-PERSON',
#  'Jewish': 'S-NORP',
#  'Pagan': 'S-NORP',
#  'Ammianus': 'S-PERSON',
#  'Nazianzen': 'E-PERSON',
#  'Athanasians': 'S-NORP',
#  'Montesquieu,': 'S-PERSON',
#  'Pagans,': 'S-NORP',
#  'Phoenicia,': 'S-GPE',
#  'Greece': 'S-GPE',
#  'Paganism,': 'S-NORP',
#  'Rome;': 'S-GPE',
#  'Numa,': 'S-PERSON',
#  'Augustus,': 'S-PERSON',
#  '(173)': 'S-CARDINAL',
#  'Christianity;': 'S-NORP',
#  'Gaul': 'S-PERSON'}

# %% [markdown]
# **Quick Pandas Dataframes Intro**

# %% [markdown]
# Beginner Tutorials: https://pandas.pydata.org/docs/getting_started/index.html#getting-started
#
#
# https://access.tufts.edu/udemy-business UDEMY is a great resource for coding tutorials.
# I especially recommend Python for Data Science and Machine Learning Bootcamp by Jose Portilla (there is a section on pandas for data science analysis)

# %%
NER_Dict
# Out:
# {'The': 'B-PERSON',
#  'Schism': 'B-PERSON',
#  'of': 'I-DATE',
#  'the': 'I-DATE',
#  'Donatists': 'S-PERSON',
#  'Arian': 'S-NORP',
#  'Controversy': 'I-WORK_OF_ART',
#  '—': 'I-WORK_OF_ART',
#  'Athanasius': 'S-PERSON',
#  'Distracted': 'I-WORK_OF_ART',
#  'state': 'I-WORK_OF_ART',
#  'Church': 'I-WORK_OF_ART',
#  'and': 'I-CARDINAL',
#  'Empire': 'I-WORK_OF_ART',
#  'under': 'I-WORK_OF_ART',
#  'Constantine': 'S-PERSON',
#  'Toleration': 'B-WORK_OF_ART',
#  'Paganism': 'S-NORP',
#  'Milan,': 'B-PERSON',
#  'Roman': 'S-NORP',
#  'Catholic': 'S-NORP',
#  'Christianity': 'S-NORP',
#  'East': 'S-LOC',
#  'Paul': 'S-PERSON',
#  'Samosata;': 'I-PERSON',
#  'Montanists': 'I-PERSON',
#  'Phrygia,': 'E-PERSON',
#  'Novatians,': 'S-NORP',
#  'Marcionites': 'S-NORP',
#  'Valentinians,': 'S-NORP',
#  'Gnostics': 'S-NORP',
#  'Asia': 'B-LOC',
#  'Egypt': 'S-GPE',
#  'Manichaeans,': 'S-NORP',
#  'Persia': 'S-GPE',
#  'Oriental': 'S-NORP',
#  'Christian': 'S-NORP',
#  'Diocletian;': 'S-PERSON',
#  'Two': 'B-DATE',
#  'Manichaeans': 'S-NORP',
#  'Constantinople;': 'S-GPE',
#  'Acesius,': 'S-PERSON',
#  'Nice;': 'S-PERSON',
#  'African': 'S-NORP',
#  '312': 'S-CARDINAL',
#  'Constantine,': 'S-GPE',
#  'Maxentius': 'S-PERSON',
#  'Africa': 'S-LOC',
#  'Columns': 'I-ORG',
#  'Hercules,': 'E-ORG',
#  'Carthage,': 'S-GPE',
#  'second': 'S-ORDINAL',
#  'West': 'S-LOC',
#  'Caecilian': 'E-GPE',
#  'Majourinus': 'S-ORG',
#  'two': 'S-CARDINAL',
#  'Cacilian': 'S-PERSON',
#  'Numidia': 'S-GPE',
#  'Caecilian,': 'S-PERSON',
#  'Majorinus,': 'S-PERSON',
#  'Numidian': 'S-NORP',
#  'Holy': 'I-WORK_OF_ART',
#  'Scriptures': 'E-PERSON',
#  'Diocletian': 'S-PERSON',
#  'Christians': 'S-NORP',
#  'five': 'S-CARDINAL',
#  'first': 'S-ORDINAL',
#  'three': 'S-CARDINAL',
#  'years': 'E-DATE',
#  'Africa,': 'E-ORG',
#  'Rome': 'S-GPE',
#  'Arles,': 'S-PERSON',
#  'Caecilian;': 'S-PERSON',
#  'Donatist': 'S-NORP',
#  'Osius': 'S-PERSON',
#  'Donatists,': 'I-PERSON',
#  'A.D': 'E-GPE',
#  '315': 'S-CARDINAL',
#  'Europe': 'S-LOC',
#  'East,': 'S-NORP',
#  'Eucharist': 'E-PERSON',
#  'Numidia,': 'S-GPE',
#  'four': 'I-DATE',
#  'hundred': 'B-CARDINAL',
#  'fourth': 'S-ORDINAL',
#  'Rogatians': 'S-NORP',
#  'Caesarean': 'I-LOC',
#  'Mauritania.(10)': 'E-LOC',
#  'Trinitarian': 'S-NORP',
#  'Clovis': 'S-PERSON',
#  'Theodoric,': 'S-PERSON',
#  'Romans': 'S-NORP',
#  'Arianism': 'S-NORP',
#  'Plato': 'S-PERSON',
#  'Christ': 'B-PERSON',
#  '360': 'E-PERSON',
#  'Plato,': 'S-GPE',
#  'Athenian': 'S-NORP',
#  'Platonic': 'S-NORP',
#  'Logos': 'S-ORG',
#  'Son': 'I-PERSON',
#  'an': 'B-DATE',
#  'Eternal': 'E-PERSON',
#  'Academy;': 'S-NORP',
#  'thirty': 'B-DATE',
#  'years.(12)': 'E-DATE',
#  'Alexandria': 'S-GPE',
#  '300': 'E-PERSON',
#  'Macedonians': 'S-NORP',
#  'Greece;': 'S-LANGUAGE',
#  'Alexandria.': 'S-GPE',
#  'Jews': 'S-NORP',
#  'Hebrews': 'S-NORP',
#  'Egyptian': 'S-NORP',
#  'One': 'S-CARDINAL',
#  'before': 'E-DATE',
#  'Christ,': 'E-PERSON',
#  'Alexandrian': 'S-NORP',
#  'Solomon': 'S-PERSON',
#  'Mosaic': 'S-NORP',
#  'Grecian': 'S-NORP',
#  'Philo,': 'S-PERSON',
#  'Hebrews;': 'S-PERSON',
#  'to': 'I-WORK_OF_ART',
#  'Jehovah': 'I-WORK_OF_ART',
#  'Moses': 'E-WORK_OF_ART',
#  'God': 'E-PERSON',
#  'Apostle': 'I-PERSON',
#  'St': 'S-GPE',
#  'John,': 'I-PERSON',
#  '97': 'S-CARDINAL',
#  'Alexandria,': 'E-PERSON',
#  'Deity,': 'E-PERSON',
#  'Academy,': 'B-PERSON',
#  'Porch,': 'E-PERSON',
#  'Nerva,': 'S-PERSON',
#  'Jesus': 'S-PERSON',
#  'Nazareth;': 'E-PERSON',
#  'Ebionites': 'S-PERSON',
#  'Docetes': 'S-ORG',
#  'Nazarenes,(23)': 'S-PERSON',
#  'Hewbrew': 'S-NORP',
#  'God,': 'E-PERSON',
#  'John': 'S-PERSON',
#  'About': 'B-DATE',
#  'fifty': 'E-CARDINAL',
#  'Ebionites,': 'S-NORP',
#  'Justin': 'B-PERSON',
#  'Martyr,': 'E-PERSON',
#  'Gnostics,': 'S-NORP',
#  'Aeon,': 'S-PERSON',
#  'Emanation': 'B-PERSON',
#  'Mount': 'S-LOC',
#  'Calvary,': 'E-LOC',
#  'Virgin,(27)': 'S-PERSON',
#  'Jordan': 'S-GPE',
#  'Pilate': 'S-PERSON',
#  'days,': 'E-DATE',
#  'Mysterious': 'B-PERSON',
#  'nature': 'I-PERSON',
#  'Trinity': 'E-PERSON',
#  'third': 'I-TIME',
#  'centuries': 'E-DATE',
#  'Trinity,(31)': 'S-PERSON',
#  'divinity': 'I-PERSON',
#  'Logos,': 'E-PERSON',
#  'Zeal': 'B-PERSON',
#  'Christians.': 'E-PERSON',
#  'Athens': 'S-GPE',
#  'Tertullian': 'S-PERSON',
#  'Greek': 'S-NORP',
#  'eternal': 'E-PERSON',
#  'Bithynia': 'S-GPE',
#  'Pliny': 'S-PERSON',
#  'Father': 'I-PERSON',
#  'Platonists:': 'S-NORP',
#  'Praxeas': 'S-GPE',
#  'Sabellius': 'S-PERSON',
#  'with': 'I-PERSON',
#  'Son,': 'E-PERSON',
#  'Sabellians': 'S-PERSON',
#  'Rome,': 'B-PERSON',
#  'Egypt,': 'E-PERSON',
#  'Alexandria;': 'S-GPE',
#  'Arius': 'S-PERSON',
#  'Alexander': 'B-PERSON',
#  'seven': 'S-CARDINAL',
#  'twelve': 'S-CARDINAL',
#  'Eusebius': 'E-PERSON',
#  'Nicomedia,': 'S-GPE',
#  'Palestine': 'S-GPE',
#  'six': 'S-CARDINAL',
#  'general': 'I-ORG',
#  'council': 'I-ORG',
#  'Nice.': 'E-ORG',
#  'Three': 'S-CARDINAL',
#  'Almighty': 'I-PERSON',
#  'Caesar': 'S-PERSON',
#  'will': 'I-PERSON',
#  'his': 'I-PERSON',
#  'Sabellian': 'S-NORP',
#  'Ebionite': 'S-NORP',
#  'Council': 'B-ORG',
#  'Nice,': 'S-PERSON',
#  '325': 'S-CARDINAL',
#  'Nice(55)': 'E-ORG',
#  'Arians': 'S-NORP',
#  'Ambrose,': 'S-PERSON',
#  'consubstantiality': 'I-PERSON',
#  'Greek,': 'I-PERSON',
#  'Latin,': 'I-PERSON',
#  'Oriental,': 'E-PERSON',
#  'Protestant': 'S-NORP',
#  'Tritheists': 'S-NORP',
#  'about': 'B-DATE',
#  'Antioch(57)': 'S-PERSON',
#  'Athanasius,': 'S-GPE',
#  'Gregory': 'B-PERSON',
#  'Nazianzen,': 'E-PERSON',
#  'Nicene': 'S-PERSON',
#  'Father,': 'E-WORK_OF_ART',
#  'Arians,(61)': 'S-PERSON',
#  'twenty': 'I-DATE',
#  'Sabellianism': 'I-PERSON',
#  'Marcellus': 'I-PERSON',
#  'Ancyra;': 'E-PERSON',
#  'Creeds': 'E-PERSON',
#  'eighteen': 'S-CARDINAL',
#  'Hilary,': 'S-PERSON',
#  'ten': 'S-CARDINAL',
#  'Poitiers': 'S-GPE',
#  'Sects': 'E-PERSON',
#  'Homoousion': 'S-PERSON',
#  'Arius,': 'S-PERSON',
#  'Atheist': 'S-NORP',
#  'Aristotle,': 'S-GPE',
#  'Aetius': 'S-PERSON',
#  'Son;': 'E-PERSON',
#  'Eusebian': 'S-NORP',
#  'Aetius;': 'S-NORP',
#  'Scriptures,': 'I-WORK_OF_ART',
#  'that': 'B-TIME',
#  'Asia;': 'S-GPE',
#  'Seleucia,': 'B-GPE',
#  'one': 'S-CARDINAL',
#  'forty-three': 'E-CARDINAL',
#  'Homoousians': 'S-NORP',
#  'Homoiousians': 'S-NORP',
#  'Catholics': 'S-NORP',
#  'bishop': 'I-PERSON',
#  'Poitiers,': 'E-PERSON',
#  'Phrygian': 'S-NORP',
#  'Semi-Arians,': 'S-NORP',
#  'Western': 'S-NORP',
#  'Latin': 'S-NORP',
#  'Asia,': 'S-NORP',
#  'Greeks,': 'S-NORP',
#  'Gallican': 'S-NORP',
#  'Hilary': 'B-PERSON',
#  'Latins': 'S-NORP',
#  'Gospel': 'S-WORK_OF_ART',
#  'Rimi,': 'I-ORG',
#  'Rimini,': 'S-GPE',
#  'Italy,': 'I-ORG',
#  'Spain,': 'B-PERSON',
#  'Gaul,': 'S-GPE',
#  'Britain,': 'E-PERSON',
#  'Illyricum': 'S-GPE',
#  'Valens': 'S-PERSON',
#  'Ursacius,': 'S-PERSON',
#  'Illyricum,': 'E-ORG',
#  'Rimini': 'S-GPE',
#  'Jerom,': 'S-PERSON',
#  'Homoousian': 'S-NORP',
#  'King': 'I-PERSON',
#  'Heaven': 'E-PERSON',
#  '324': 'S-CARDINAL',
#  'Constantine,(78)': 'S-PERSON',
#  'Osius,': 'S-PERSON',
#  'Constantine;': 'S-PERSON',
#  'Casarea': 'S-GPE',
#  'Nicomedian': 'I-WORK_OF_ART',
#  'months': 'E-DATE',
#  'Illyricum;': 'S-GPE',
#  'Porphyrians;': 'S-PERSON',
#  'Christ.(82)': 'S-PERSON',
#  'Eusebius,': 'S-PERSON',
#  'Jerusalem;': 'S-GPE',
#  'Constantinople': 'S-GPE',
#  'same': 'I-DATE',
#  'day': 'E-DATE',
#  'Eustathius': 'S-PERSON',
#  'Antioch,': 'B-WORK_OF_ART',
#  'Nicomedia': 'S-GPE',
#  'Nice': 'B-PERSON',
#  'Constantius': 'S-PERSON',
#  'Constantius,': 'S-GPE',
#  'Magnentius': 'S-PERSON',
#  'Mursa,': 'S-PERSON',
#  'war,': 'B-PERSON',
#  'son': 'I-PERSON',
#  'Gallic': 'S-NORP',
#  'Arians,': 'S-NORP',
#  'Cyril,': 'S-PERSON',
#  'Jerusalem,': 'S-GPE',
#  'Pentecost,': 'S-EVENT',
#  'hour': 'E-TIME',
#  'Olives,': 'E-LOC',
#  'Councils': 'E-ORG',
#  'Ammianus,': 'S-PERSON',
#  'Sirmium,': 'E-FAC',
#  'Constantinople,': 'S-GPE',
#  'eunuchs,': 'I-PERSON',
#  'women,': 'E-PERSON',
#  'Homoousion;': 'S-NORP',
#  'Gallus;': 'S-PERSON',
#  'Imperial': 'S-NORP',
#  'Antioch': 'S-GPE',
#  'Semi-Arian': 'S-NORP',
#  'Isauria;': 'S-GPE',
#  'Hadriatic,': 'S-LOC',
#  'days': 'E-DATE',
#  'seventh': 'S-ORDINAL',
#  'Praetorian': 'S-PERSON',
#  'fifteen': 'S-CARDINAL',
#  'God.(95)': 'E-PERSON',
#  'Trinity,': 'S-NORP',
#  'Alexander,': 'S-PERSON',
#  'deacon': 'I-PERSON',
#  'Five': 'S-CARDINAL',
#  'Basil;': 'S-PERSON',
#  'Alexandrians': 'S-NORP',
#  'Nile': 'S-LOC',
#  'Ethiopia;': 'S-GPE',
#  '330': 'S-CARDINAL',
#  'Meletius.(102)': 'B-PERSON',
#  'Arsenius,': 'S-PERSON',
#  'Dalmatius,': 'S-PERSON',
#  'Caesarea': 'S-GPE',
#  'Tyre': 'S-GPE',
#  'Jerusalem': 'S-GPE',
#  'Meletians;': 'S-PERSON',
#  'Arsenius': 'S-NORP',
#  'Caesarea,': 'S-GPE',
#  '336': 'S-CARDINAL',
#  'Tyre,': 'S-GPE',
#  "Constantine's": 'S-PERSON',
#  'Treves,': 'B-ORG',
#  'twenty-eight': 'I-DATE',
#  '338': 'S-CARDINAL',
#  '341': 'S-CARDINAL',
#  'Eusebians': 'S-PERSON',
#  'Ninety': 'S-CARDINAL',
#  'Semi-Arianism,': 'S-NORP',
#  'twenty-five': 'S-CARDINAL',
#  'Greeks': 'S-NORP',
#  'Athanasius;': 'S-PERSON',
#  'Gregory,': 'S-PERSON',
#  'Asiatic': 'S-NORP',
#  'Julius:': 'S-PERSON',
#  'Italy': 'S-GPE',
#  'Milan': 'S-GPE',
#  'Constans,': 'S-PERSON',
#  'Constans': 'S-NORP',
#  'Ninety-four': 'S-CARDINAL',
#  'West,': 'S-LOC',
#  'Sardica,': 'S-GPE',
#  'dominions': 'I-PERSON',
#  'protector': 'I-PERSON',
#  'Thrace;': 'S-GPE',
#  'East.(115)': 'B-ORG',
#  'Sardica': 'E-ORG',
#  '349': 'S-CARDINAL',
#  'Capua,': 'S-GPE',
#  'Lodi,': 'B-ORG',
#  'Verona,': 'I-ORG',
#  'Padua,': 'I-ORG',
#  'Aquileia,': 'E-ORG',
#  'Treves': 'S-GPE',
#  'Syria;': 'S-NORP',
#  'Constantius;': 'S-PERSON',
#  'Alexandrians;': 'S-PERSON',
#  'Ethiopia': 'S-GPE',
#  '351': 'S-CARDINAL',
#  'years,': 'E-DATE',
#  'Arles': 'S-GPE',
#  'Eastern': 'S-NORP',
#  'Archbishop': 'I-PERSON',
#  'Sardica(126)': 'S-GPE',
#  '355': 'S-CARDINAL',
#  'Athanasius)': 'S-PERSON',
#  'Eastern,': 'S-NORP',
#  'Liberius': 'S-PERSON',
#  'Cordova,': 'S-PERSON',
#  'Paulinus': 'E-PERSON',
#  'Dionysius': 'E-ORG',
#  'Vercellae,': 'B-PERSON',
#  'Lucifer': 'E-PERSON',
#  'Cagliari,': 'S-GPE',
#  'Liberius,': 'S-PERSON',
#  'Cordova': 'S-GPE',
#  'Spaniard': 'S-NORP',
#  'Maximian': 'S-PERSON',
#  'Roman,': 'E-PERSON',
#  'Beraea': 'S-PERSON',
#  'Thrace,': 'S-PERSON',
#  'years;': 'E-DATE',
#  'Cappadocia,': 'S-GPE',
#  'likeness,': 'I-PERSON',
#  'Third': 'S-ORDINAL',
#  '356': 'S-CARDINAL',
#  'Six-and-twenty': 'B-DATE',
#  'court': 'E-ORG',
#  'Upper': 'I-PERSON',
#  'Libya,': 'S-NORP',
#  'twenty-three': 'B-DATE',
#  'Syrianus,': 'B-PERSON',
#  'duke': 'I-PERSON',
#  'thousand': 'S-CARDINAL',
#  'Syrianus': 'S-GPE',
#  'Pagans': 'S-NORP',
#  'George': 'S-PERSON',
#  'Cappadocia': 'S-GPE',
#  'Sebastian,': 'S-PERSON',
#  'more': 'B-CARDINAL',
#  'than': 'I-CARDINAL',
#  'ninety': 'E-CARDINAL',
#  'George,': 'S-PERSON',
#  'memorable': 'I-TIME',
#  'night': 'E-TIME',
#  'Theonas': 'S-PERSON',
#  'David': 'S-PERSON',
#  'Israel': 'S-GPE',
#  'moment': 'E-TIME',
#  '356-362': 'S-CARDINAL',
#  'Ethiopia,': 'S-NORP',
#  'Antony': 'S-PERSON',
#  'Pachomius': 'S-PERSON',
#  'Nile;': 'S-LOC',
#  'Tabenne': 'S-PERSON',
#  'several': 'B-CARDINAL',
#  'only': 'B-DATE',
#  'age,': 'E-DATE',
#  'midnight,': 'E-TIME',
#  '(143)': 'E-GPE',
#  'Mediterranean': 'S-LOC',
#  'Arians;': 'S-PERSON',
#  'Anti-christ': 'I-PERSON',
#  'church': 'E-PERSON',
#  'Gallus,': 'S-PERSON',
#  'Sylvanus,': 'S-PERSON',
#  'Magnentius,': 'S-PERSON',
#  'Bishops': 'E-PERSON',
#  'Christians,': 'S-NORP',
#  'Flavianus': 'B-ORG',
#  'Diodorus,': 'E-ORG',
#  'Glory': 'I-WORK_OF_ART',
#  'Ghost': 'E-WORK_OF_ART',
#  'three,': 'B-CARDINAL',
#  'or': 'I-CARDINAL',
#  'even': 'I-CARDINAL',
#  'Felix,': 'S-ORG',
#  'Circus': 'S-FAC',
#  'Felix': 'S-PERSON',
#  'Marius': 'S-PERSON',
#  'Flavian': 'S-NORP',
#  'Infidels,': 'S-NORP',
#  'episcopal': 'E-PERSON',
#  'Macedonius': 'S-PERSON',
#  'space': 'I-DATE',
#  'fourteen': 'I-DATE',
#  'Mesopotamia': 'S-LOC',
#  'Hermogenes,': 'S-PERSON',
#  'master-general': 'I-PERSON',
#  'cavalry,': 'E-PERSON',
#  'Hermogenes': 'S-PERSON',
#  'Philip,': 'S-PERSON',
#  'Zeuxippus,': 'S-GPE',
#  'Thessalonica': 'S-GPE',
#  'Macedonius,': 'S-PERSON',
#  'Acacius': 'S-PERSON',
#  'Cruelty': 'B-PERSON',
#  'Theodosian': 'S-NORP',
#  'Christians;': 'S-NORP',
#  'Thrace': 'S-LOC',
#  'Minor': 'E-LOC',
#  'Macedonius;': 'S-GPE',
#  'Homoiousion': 'S-PERSON',
#  'Novatians': 'S-NORP',
#  'Paphlagonia': 'S-GPE',
#  'Mantinium': 'S-GPE',
#  'Novatian': 'S-NORP',
#  'Paphlagonians': 'S-NORP',
#  '345': 'S-CARDINAL',
#  'Circumcellions,': 'S-PERSON',
#  'Macarius,': 'S-PERSON',
#  'Mauritania': 'S-GPE',
#  'Gaetulian': 'I-LOC',
#  'desert,': 'E-LOC',
#  'Circumcellions': 'S-PERSON',
#  'Bagai': 'S-GPE',
#  'beginning': 'I-DATE',
#  'present': 'I-DATE',
#  'century': 'E-DATE',
#  'Camisards;': 'S-PERSON',
#  'Languedoc': 'S-GPE',
#  'Africans': 'S-NORP',
#  'Satan,': 'S-PERSON',
#  'Jewish': 'S-NORP',
#  'Pagan': 'S-NORP',
#  'Ammianus': 'S-PERSON',
#  'Nazianzen': 'E-PERSON',
#  'Athanasians': 'S-NORP',
#  'Montesquieu,': 'S-PERSON',
#  'Pagans,': 'S-NORP',
#  'Phoenicia,': 'S-GPE',
#  'Greece': 'S-GPE',
#  'Paganism,': 'S-NORP',
#  'Rome;': 'S-GPE',
#  'Numa,': 'S-PERSON',
#  'Augustus,': 'S-PERSON',
#  '(173)': 'S-CARDINAL',
#  'Christianity;': 'S-NORP',
#  'Gaul': 'S-PERSON'}

# %%
ner_frame= pd.DataFrame.from_dict(NER_Dict, orient= 'index')
ner_frame
# Out:
#                         0
# The              B-PERSON
# Schism           B-PERSON
# of                 I-DATE
# the                I-DATE
# Donatists        S-PERSON
# ...                   ...
# Numa,            S-PERSON
# Augustus,        S-PERSON
# (173)          S-CARDINAL
# Christianity;      S-NORP
# Gaul             S-PERSON
#
# [524 rows x 1 columns]

# %%
#creates a new index of numbers that is not the entity 
ner_frame.reset_index(inplace=True)

# %%
ner_frame.rename(columns={'index':'token', 0: 'NER_tag'})
# Out:
#              token     NER_tag
# 0              The    B-PERSON
# 1           Schism    B-PERSON
# 2               of      I-DATE
# 3              the      I-DATE
# 4        Donatists    S-PERSON
# ..             ...         ...
# 519          Numa,    S-PERSON
# 520      Augustus,    S-PERSON
# 521          (173)  S-CARDINAL
# 522  Christianity;      S-NORP
# 523           Gaul    S-PERSON
#
# [524 rows x 2 columns]

# %%
NER_tags= { 'PER':'People, including fictional characters', 'NORP':'Nationalities, religious and political groups: Jewish, Buddhist',
           'TIME':'Time shorter than a day','ORG':'Companies, agencies, institutions', 'GPE':'Countries, cities, regions (districts)',
'LOC':'Geographical entities', 'PRODUCT':'Objects, vehicles, foods', 'EVENT':'Named battles, wars, sports events, catastrophes',
'QUANTITY':'Measurements: 10 kg, 200 km', 'ORDINAL':'Numbers of order: first ,third','CARDINAL': 'Numerals that do not fall under another type',
'FAC': 'Buildings, airports, roads', 'LANGUAGE':'Any named language'}
NER_tags
# Out:
# {'PER': 'People, including fictional characters',
#  'NORP': 'Nationalities, religious and political groups: Jewish, Buddhist',
#  'TIME': 'Time shorter than a day',
#  'ORG': 'Companies, agencies, institutions',
#  'GPE': 'Countries, cities, regions (districts)',
#  'LOC': 'Geographical entities',
#  'PRODUCT': 'Objects, vehicles, foods',
#  'EVENT': 'Named battles, wars, sports events, catastrophes',
#  'QUANTITY': 'Measurements: 10 kg, 200 km',
#  'ORDINAL': 'Numbers of order: first ,third',
#  'CARDINAL': 'Numerals that do not fall under another type',
#  'FAC': 'Buildings, airports, roads',
#  'LANGUAGE': 'Any named language'}

# %%
nested_NER_prefixes= {'B':'Beginning of named entity','I':'Token is inside a named entity','O':'Corresponding word is not an entity','E':'End of named entity','S':'Named entity has only one token/element'}
nested_NER_prefixes
# Out:
# {'B': 'Beginning of named entity',
#  'I': 'Token is inside a named entity',
#  'O': 'Corresponding word is not an entity',
#  'E': 'End of named entity',
#  'S': 'Named entity has only one token/element'}

# %%
nertags_frame= pd.DataFrame.from_dict(NER_tags, orient= 'index')
nertags_frame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nertags_frame= pd.DataFrame.from_dict(NER_tags, orient= 'index')
#       2 nertags_frame
#
# NameError: name 'pd' is not defined

# %%
nertags_frame.reset_index(inplace=True)

# %%
nertags_frame.rename(columns={'index':'tag', 0: 'example'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nertags_frame.rename(columns={'index':'tag', 0: 'example'})
#
# NameError: name 'nertags_frame' is not defined

# %%
bioestags_frame= pd.DataFrame.from_dict(nested_NER_prefixes, orient= 'index')
bioestags_frame

# %% [markdown]
# After what we have seen today, how would you describe a named entity?
# Do these named entities tell you anything about the contents of this chapter?

# %% [markdown]
# In this notebook, what inputs did we give stanza to process?
# What outputs does stanza produce?
# How did we access the different components of this output? (ie pos, lemma, ner, etc.)

# %% [markdown]
# Do you have any remaining questions or things that feel unclear after this demo?
